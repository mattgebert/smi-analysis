# %% [markdown]
# # SMI Data Reduction for Grazing-Incidence Energy Scans

# %% [markdown]
# ### Setup
# ##### Package imports

# %%
import os
# os.environ["OMP_NUM_THREADS"] = "1" # Prevent numpy from using multiple threads when using emcee multiprocessing.
# These packages should all be installed if the procedure was followed
# %matplotlib inline
import matplotlib, matplotlib.pyplot as plt, matplotlib.colors as mplc
from smi_analysis import SMI_beamline
import numpy as np, numpy.typing as npt
import pandas as pd
import fabio
import logging
import scipy.constants as const
import time
import corner
from typing import Literal, Callable
import emcee
import tqdm, tqdm.notebook # For progress bars
from scipy.optimize import curve_fit
import warnings

# Setup options
fabio.TiffIO.logger.setLevel(logging.ERROR)
pd.set_option("display.width", 1000) #display large filenames
pd.set_option('max_colwidth', None)
# Out:
# WARNING:pygix.transform:Unable to import pyFAI.ocl_azim: cannot import name 'ocl_azim' from 'pyFAI' (/nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_azim_csr: cannot import name 'ocl_azim_csr' from 'pyFAI' (/nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_azim_lut for: cannot import name 'ocl_azim_lut' from 'pyFAI' (/nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/pyFAI/__init__.py)
# ERROR:pygix.transform:Unable to import pyFAI.ocl_sort for: cannot import name 'ocl_sort' from 'pyFAI' (/nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/pyFAI/__init__.py)

# %%
# Define some useful functions
en2wav = lambda en: const.h * const.c / (const.e * en)
"""Function to convert energy (eV) to wavelength"""
en2wav(2.45e3)
# Out:
# 5.060579527885725e-10

# %%
DRIVE = "/"

# %% [markdown]
# ##### Experimental configuration

# %%
geometry: Literal['Transmission'] | Literal['Reflection'] = 'Reflection'
"""The measurement geometry"""
energy: float = 2.45e3
"""The energy (keV) at which the scan is performed"""
wavelength: float = en2wav(energy)
"""The wavelength corresponding to `energy`.""" 
beamstop_type: Literal["pindiode"] | Literal['rod'] | None = None # Angle selected away from beam so no need for beamstop.
"""The beamstop type"""
incident_angle = 0
"""The default incident angle (varies) in degrees"""

#WAXS
detector_waxs: Literal['Pilatus900kw'] | Literal['Pilatus1m'] = 'Pilatus900kw'
"""Type of WAXS/SAXS detector"""
sdd_waxs: float | int = 280 # In mm
"""Sample to detector distance in millimeters"""
center_waxs: tuple[int|float, int|float] = (#208, 97)
                                            223, 97)
"""Coordinates of the beam centre at 0 degrees, for the middle detector strip"""
bs_pos_waxs: list[tuple[int, int]] = [(0, 0),
                                      (0, 0), 
                                      (0, 0)
                                     ]
"""The position of the center of the beam stop for each detector angle; [0,0] implies not measured. 
This coordinate is relative to the stitch of the 3 detector strips."""
detector_angles: list[int | float] | npt.NDArray[np.float64 | np.int_] = np.deg2rad(np.array([17.7]) - 0.06) #0.06 is the correction for the WAXS 0 deg detector position
"""The angles of the detector in radians. 
May need to include corrections (-0.06 degs at 0, -0.36 at 20 deg) for position offsets."""


display(pd.DataFrame([
    ("Geometry", geometry),
    ("Energy (keV)", energy),
    ("Wavelength (nm)", wavelength * 1e9),
    ("Sample to Detector Distance (mm)", sdd_waxs),
    ("Beamstop Type", beamstop_type),
    ("Incident Angle (deg)", incident_angle),
    ("Detector Type", detector_waxs),
    ("Center Coords", center_waxs),
    ("Beamstop Coords", bs_pos_waxs),
    ("Detector Angles", detector_angles)
], columns=["Parameter", "Value"]))

#Test the configuration can be loaded!
SMI_waxs = SMI_beamline.SMI_geometry(geometry = geometry,
                                     wav = wavelength,
                                     sdd = sdd_waxs,
                                     alphai = incident_angle,
                                     detector = detector_waxs,
                                     center = center_waxs,
                                     bs_pos = bs_pos_waxs,
                                     bs_kind = beamstop_type,
                                     det_angles=detector_angles)


angles = [detector_angles[0] - np.deg2rad(7.47), detector_angles[0], detector_angles[0] + np.deg2rad(7.47)]
SMI_waxs.calculate_integrator_gi(angles)
# Out:
#                           Parameter                     Value
# 0                          Geometry                Reflection
# 1                      Energy (keV)                    2450.0
# 2                   Wavelength (nm)                  0.506058
# 3  Sample to Detector Distance (mm)                       280
# 4                     Beamstop Type                      None
# 5              Incident Angle (deg)                         0
# 6                     Detector Type              Pilatus900kw
# 7                     Center Coords                 (223, 97)
# 8                   Beamstop Coords  [(0, 0), (0, 0), (0, 0)]
# 9                   Detector Angles      [0.3078760800517997]

# %% [markdown]
# ### Flatfield Data
# Data to normalise the detector pixels and remove background.

# %%
# Past beamline data for flat fielding (normalizing default pixel intensities)
# Note this is done at 2478eV, not all energies.

DRIVE = "/"

# # 2024 Cycle 2 Flatfielding
# CYCLE_FLAT = '2024_3'
# PROPOSAL_FLAT= '314483-Freychet-Flatfielding'
# FLAT_FILE = 'GF_flatfield_Sedge_2450uhighg1600_WZY11_wa30deg_2478eV_20s_id701601_000000_WAXS.tif'

# 2024 Cycle 3 Flatfielding
PROPOSAL_FLAT= '314483_Freychet_15'
FLAT_FILE = 'GF_flatfield_energy2450.00eV_uhighg1600_AEM_3s_2830.00eV_wa40.0_id891696_000000_WAXS.tif'

# Compile and load the flatfield path
FLAT_DIR_PATH = f'{DRIVE}/nsls2/data/smi/legacy/results/data/2025_1/{PROPOSAL_FLAT}/900KW/'
flatfield: npt.NDArray = np.rot90(fabio.open(os.path.join(FLAT_DIR_PATH, FLAT_FILE)).data, 1)

fig,ax = plt.subplots(2,1, sharex=True, sharey=True, figsize=(8,5))
p = 99.9
percentile = np.percentile(flatfield, p) #99.9th percentile
ax[0].imshow(np.rot90(flatfield, 3), vmin=0, vmax=percentile, interpolation=None)
ax[0].set_title("Flatfielding Data")

erronous =  (flatfield > percentile) * 1.0
ax[1].imshow(np.rot90(erronous,3), vmin=0, vmax=np.max(erronous)/5, interpolation=None)
ax[1].set_title(f"{p}th percentile pixels")
fig.tight_layout()
# plt.close()

# %% [markdown]
# ### Extra functions for SMI Beamline Masking
#
# ##### Detector Masking

# %%
def apply_detector_mask_to_array(
    mask: npt.NDArray = np.zeros((1475, 195), dtype=bool)
) -> npt.NDArray[np.bool_]:
    """Sets an array mask for bad pixels; should only be applied to the middle column array"""
    mask[1254:1256, 47] = True
#     mask[979:1050, 0:100] = True
    mask[967, 67] = True
#     mask[490:555, 100:] = True
    mask[1231:1233, 174] = True
    mask[1414: 1416, 179] = True
    mask[858:860, 5] = True
    mask[414, 6] = True
    mask[394, 138] = True
    mask[364:366, 41] = True
    mask[364:366, 96] = True
    mask[304:306, 96:98] =  True
    mask[988, 188:194] = True
    mask[:, 1] = True
    mask[473, 20] = True
    mask[98, 5] = True
    mask[141, 111] = True
#     mask[240:300, 0:50] = True
#     mask[300:425, 125:] = True
    mask[181:183, 97:99] = True
    mask[553:555, 99:100] = True
    # Mask out the final column for the middle row.
    mask[:1475//3] = True

    return mask

def apply_boundary_mask_to_array(
    mask: npt.NDArray = np.zeros((1475, 195), dtype=bool)
) -> npt.NDArray[np.bool_]:
    """Sets an array mask for the boundary pixels; should only be applied to the middle column array"""
    mask[0, :] = True
    mask[-1, :] = True
    mask[:, 0] = True
    mask[:, -1] = True
    return mask

def apply_detector_mask(geom: SMI_beamline.SMI_geometry) -> None:
    """Applies a pre-defined mask for the bad pixels in the SMI beamline"""
    for i, mask in enumerate(geom.masks):
        # Dead pixels in the 2nd detector strip.
        if i%3 == 1: # For multiple WAXS images, always masks the 2nd strip.
            apply_detector_mask_to_array(mask)
        # Add a mask on the boundary
        apply_boundary_mask_to_array(mask)
    return

# %% [markdown]
# ##### Flatield Masking

# %%
FLATFIELD_PERCENTILE = 97.5
"""The percentile of the flatfield data to mask."""
# SAMPLE_PERCENTILE = 100.00
SAMPLE_PERCENTILE = 100.00
"""The percentile of the real data to mask."""

# For flatfielding, ignore/mask reigons between detector pixels.
FLATFIELD_SLICES = [slice(0, 195),  # Ign. flatfield above first frame
                    slice(211, 406),# Ign. flatfield outside middle  
                    slice(-195, None)] # Ign. flatfield below first frame
            
def flatfield_mask(flatfield: npt.NDArray = flatfield, 
                   percentile: float = FLATFIELD_PERCENTILE, 
                   min: float | int = 0) -> npt.NDArray[np.bool_]:
        """
        Returns a mask of flatfield data as a boolean numpy array.
        
        Masks pixels above the `percentile` (by default 99.9)
        and values less than `min` (by default 1).
        """
        # Calculate the 99.9th percentile of the total flatfield data
        p = np.percentile(flatfield, percentile) #99.9th percentile
        erronous =  flatfield > p
        # Also mask pixels well away from the standard deviation
        mean = np.mean(flatfield)
        std = np.std(flatfield)
        erronous |= flatfield > mean + 5*std
        
        # Also mask negative and zero pixels
        negative = flatfield < min
        # Return the overlap of the erronous and negative masks.
        return erronous | negative

def apply_flatfield(geom: SMI_beamline.SMI_geometry, 
                    flatfield: npt.NDArray, 
                    flat_percentile: float | int = FLATFIELD_PERCENTILE,
                    img_percentile: float | int = SAMPLE_PERCENTILE,
                    outliers: bool = False,
                    min : float | int = 1) -> None:
    """Applies a pre-defined flatfield mask and normalisation for the SMI beamline object"""
    flatmask = flatfield_mask(flatfield=flatfield, percentile=flat_percentile, min = min)
    for i, (mask, img) in enumerate(zip(geom.masks, geom.imgs)):
        fmask_i = flatmask[:, FLATFIELD_SLICES[i % 3]]
        # Apply the masking values
        masking_values = np.where(fmask_i == True)
        mask[masking_values] = True
        # Apply the normalisation 
        flat = flatfield[:, FLATFIELD_SLICES[i%3]] # Get flatfield panel
        flat[flat < 0] = 10000 # avoid negative values - note these are already masked
        # Multiply img by max of flatfield, then divide by flatfield to keep integer precision of img.
        temp = ((img * np.max(flatfield[:, FLATFIELD_SLICES[i%3]] * ~mask))
                / (flat * ~mask +1)) * ~mask # Avoid divide by zero, and zero mask values.
        # This line creates a runtime error due to casting... img is int32, flat is float64
        img[:] = temp.astype(np.int32)
    
        # Repeat mask for very large values erronously normalised
        if not img_percentile is None and img_percentile < 100:
            mask2 = flatfield_mask(flatfield=img, percentile=img_percentile, min = 0) # only consider positive values.
            masking_values2 = np.where(mask2 == True)
            mask[masking_values2] = True
        
        # Mask outliers in the data
        if outliers:
            img_mean = np.mean(img[~mask])
            img_std = np.std(img[~mask])
            mask[img > img_mean + 10*img_std] = True
    return

# %% [markdown]
# ##### Show the stages of Flatfield masking

# %%
fig,ax = plt.subplots(2,2, figsize=(16,6), dpi=50, sharex=True, sharey=True)

# Detector image is (619, 1475) #619 is 195 * 3 + 2 * 17
# Show the detector masking
grid = np.zeros((195, 1475), dtype=bool)


det_mask = np.c_[apply_boundary_mask_to_array(grid.copy().T),
                 np.zeros((17, 1475), dtype=bool).T,
                 apply_detector_mask_to_array(apply_boundary_mask_to_array(grid.copy().T)), # 195 pixels
                 np.zeros((17, 1475), dtype=bool).T,
                apply_boundary_mask_to_array(grid.copy().T)]
    

det_im = ax[0][0].imshow(np.rot90(det_mask,3), interpolation='nearest') # required to prevent interpolation
ax[0][0].set_title("Pre-defined Detector Mask (boolean)")

# Show the flatfield masking
ff_masked = flatfield_mask(flatfield)
ff_masked_im = ax[0][1].imshow(np.rot90(ff_masked,3), interpolation='nearest') # required to prevent interpolation
ax[0][1].set_title("Calculated Flatfield Mask (boolean)")

# Show the flatfield image
ff_im = ax[1][0].imshow(np.rot90(flatfield,3), vmin = 0, vmax = np.mean(flatfield[~ff_masked]) + 5*np.std(flatfield[~ff_masked]), interpolation='nearest')
plt.colorbar(ff_im)
ax[1][0].set_title("Flatfield Raw Data")

# Show the masks on the flatfield image
joined_mask = ff_masked | det_mask
cmap = mplc.LinearSegmentedColormap.from_list("Mask", [(256,0,0,0),(256,0,0,256)], N=2)
ff_im_masked = ax[1][1].imshow(np.rot90(flatfield,3), interpolation='nearest',
                               vmin = 0, vmax = np.mean(flatfield[~ff_masked]) + 5*np.std(flatfield[~ff_masked]))
ax[1][1].imshow(np.rot90(joined_mask,3), cmap=cmap, interpolation='nearest')
ax[1][1].set_title("Flatfield Data Masked")

fig.tight_layout()
plt.show()
# plt.close()

# %% [markdown]
# ### Energy Dependence Flux Calibration for MEX2 Beamline

# %%
## Flux data from recording photodiode and BPMs
# 2024 Cycle 3 Flux
PROPOSAL_FLUX = '316022_McNeill_02'

# Compile and load the flux paths
FLUX_DIR_PATH = f'{DRIVE}nsls2/data/smi/legacy/results/data/2025_1/{PROPOSAL_FLUX}/1M/'
FLUX_FILES = [file for file in os.listdir(FLUX_DIR_PATH) if file.endswith('.tif') and "Sedge" in file and "eV" in file]

# Parse the flux data from the filenames
flux_energies = []
flux_norm_bpm2 = []
"""A collection of flux normalisation values for each flux file, also known as i0."""
flux_norm_bpm3 = []
"""A collection of flux normalisation values for each flux file, also known as i0."""
flux_norm_phd = []
"""A collection of flux normalisation values for each flux file, also known as i0."""
for file in FLUX_FILES:
    # Example Format:
    # CM_direct_beam_Sedge_2474.75eV_bpm2_124.304_bpm3_4.511_pd_20611.340_id806560_000000_SAXS.tif'
    en_idx = file.find('eV')
    en = float(file[en_idx-7:en_idx])
    bpm2_idx = file.find('bpm2_')
    bpm3_idx = file.find('bpm3_')
    phd_idx = file.find('pd_')
    bpm2 = float(file[bpm2_idx+5:bpm3_idx-1])
    bpm3 = float(file[bpm3_idx+5:phd_idx-1])
    phd = float(file[phd_idx+3:file.find('_id')])
    flux_energies.append(en)
    flux_norm_bpm2.append(bpm2)
    flux_norm_bpm3.append(bpm3)
    flux_norm_phd.append(phd)
    
# Sort the flux data by energy
idx = np.argsort(flux_energies)
flux_energies = np.array(flux_energies)[idx].tolist()
flux_norm_bpm2 = np.array(flux_norm_bpm2)[idx]
flux_norm_bpm3 = np.array(flux_norm_bpm3)[idx]
flux_norm_phd = np.array(flux_norm_phd)[idx]

# Normalise
flux_norm_bpm2 /= flux_norm_bpm2[-1]
flux_norm_bpm3 /= flux_norm_bpm3[-1]
flux_norm_phd /= flux_norm_phd[-1]

fig,ax = plt.subplots(1,1, figsize=(8, 3), sharex=True)
ax.plot(flux_energies, flux_norm_bpm2, label="BPM2")
ax.plot(flux_energies, flux_norm_bpm3, label="BPM3")
ax.plot(flux_energies, flux_norm_phd, label="PHD")
ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Flux (Arbitrary Units)")
ax.set_title("Flux Normalisation")
ax.legend()

# %%
fig,ax = plt.subplots(1,1, figsize=(8, 3), sharex=True)
ax.plot(flux_energies, flux_norm_bpm2, label="BPM2")
ax.plot(flux_energies, flux_norm_bpm3, label="BPM3")
ax.plot(flux_energies, flux_norm_phd, label="PHD")
ax.set_xlabel("Energy (keV)")
ax.set_ylabel("Flux (Arbitrary Units)")
ax.set_title("Flux Normalisation")

FLUX_OPTIONS: dict[str, dict[str, npt.NDArray]] = {}
FLUX_NORM: dict[str, npt.NDArray] = {}

for ai in ["ai0.40", "ai0.80", "ai4.00", "ai8.00"]:
    ## Additional flux data from silicon reference samples
    # Define the silicon reference data
    WAXS_ANGLE_STRINGS = ['wa0']
    FLUX_SI_CYCLE: str = '2025_1' #YYYY_[1-3]
    FLUX_SI_PROPOSAL_ID = '316022_McNeill_05' #PPPPPP_[Name]_[#]
    FLUX_SI_DIR = f'{DRIVE}nsls2/data/smi/legacy/results/data/2025_1/{FLUX_SI_PROPOSAL_ID}/900KW/'

    # Load the flux filenames
    FLUX_SI_FILES = [file for file in os.listdir(FLUX_SI_DIR) 
                    if file.endswith('.tif') 
                    and "_Si_" in file 
                    and "wide" not in file
                    and "calibrationai" not in file
                    # and "clean" in file
                    # and (ai in file and "redo" not in file
                    #      if "redo" not in ai
                    #      else (ai[:-6] in file and "redo" in file))]
                    and "redo" in file
    ]   
    
    print(len(FLUX_SI_FILES), ai)
    
    if len(FLUX_SI_FILES) == 0:
         print(f"No files found for {ai}")
         #Skip
         continue
    
    flux_energies2 = []
    for j, file in enumerate(FLUX_SI_FILES):
        en_idx = file.find('eV')
        en = file[en_idx-7:en_idx]
        flux_energies2.append(float(en))
        # Sort the flux energies
        flux_energies2 = sorted(flux_energies2)
    
    FLUX_SI_DATASETS: list[list[str]] = [[""] * len(WAXS_ANGLE_STRINGS) for _ in flux_energies2]
    """For each energy, a list of raw data filenames for the silicon reference."""
    for j, file in enumerate(FLUX_SI_FILES):
        en_idx = file.find('eV')
        en = file[en_idx-7:en_idx]
        energies_idx = flux_energies2.index(float(en))
        waxs_angle_idx = [k for k, angle in enumerate(WAXS_ANGLE_STRINGS) if angle in file][0]
        FLUX_SI_DATASETS[energies_idx][waxs_angle_idx] = file

    pixel_summations: npt.NDArray[float] = np.zeros((len(flux_energies2), len(WAXS_ANGLE_STRINGS)))
    """The pixel summations for each sample, energy, and WAXS angle."""
    for j, en in enumerate(flux_energies2):
        for k, angle in enumerate(WAXS_ANGLE_STRINGS):
            if FLUX_SI_DATASETS[j][k] != "":
                # Load the data
                img = fabio.open(os.path.join(FLUX_SI_DIR, FLUX_SI_DATASETS[j][k])).data
                # Mask the data
                new_mask = np.zeros_like(img, dtype=bool).T
                apply_boundary_mask_to_array(new_mask)
                apply_detector_mask_to_array(new_mask)
                new_mask = new_mask.T
                img_mask = flatfield_mask(img, FLATFIELD_PERCENTILE, 0)

                # Perform a summation excluding masked pixels:
                img[img_mask | new_mask] = 0

                #619, 1475 only use middle module
                # Columns
                img[0:619//3] = 0
                # img[619//3 : 2*619//3] = 0
                img[2*619//3:] = 0
                # Rows
                img[:, 0:1475//3] = 0
                # img[:, 1475//3 : 2*1475//3] = 0
                img[:, 2*1475//3:] = 0

                # if j == 0 and k == 0:
                #     plt.figure()
                #     plt.imshow(img)
                #     display(img_mask.shape)

                pixel_summations[j][k] = np.sum(img)
    
    # Normalize the pixel summations
    print(f"{ai}", pixel_summations[-2])
    pixel_summations /= pixel_summations[-2]
    si_ave = np.mean(pixel_summations, axis=1)

    # Plot results
    for k, angle in enumerate(WAXS_ANGLE_STRINGS):
        ax.plot(flux_energies2, pixel_summations[:, k], label=f'Si {angle} {ai}')

    # Select a flux channel for the analysis
    FLUX_CHANNEL = 'si_ave'
    match FLUX_CHANNEL:
        case 'si18':
                FLUX_NORM[ai] = pixel_summations[:, 0]
        case 'si_ave':
                FLUX_NORM[ai] = si_ave
        case _:
                raise ValueError("Invalid flux channel selected.")
    
    FLUX_OPTIONS[ai] = {
        'si18': pixel_summations[:, 0],
        'si_ave': si_ave
    }

# TODO: Change when we get good Si data.
FLUX_NORM["ai0.40"] = FLUX_NORM["ai0.80"]

fig.tight_layout()
fig.legends
fig.legend()
display(fig)
# Out:
# 63 ai0.40
# ai0.40 [5412.]
# 63 ai0.80
# ai0.80 [21166.]
# 37 ai4.00
# ai4.00 [2109786.]
# 0 ai8.00
# No files found for ai8.00
# 63 ai0.40_redo
# ai0.40_redo [3094866.]

# %% [markdown]
# ### Data Import
#
# ##### Locate the files on your computer and define the output directory

# %%
CYCLE: str = '2024_3' #YYYY_[1-3]
PROPOSAL_ID = '316022_McNeill_03' #PPPPPP_[Name]_[#]
## ----------- Path to the raw data -----------

# RAW_PATH = f'D:/Datasets/2024-09 SMI/{CYCLE}/{PROPOSAL_ID}/900KW/'
RAW_DIR = f'{DRIVE}/nsls2/data/smi/legacy/results/data/2025_1/{PROPOSAL_ID}/900KW/'
display(pd.DataFrame(os.listdir(RAW_DIR), columns=["Filename"])) #use tail or head to display a subset

## ----------- Create/select the results directory -----------
RESULT_DIR = f'{DRIVE}/nsls2/data/smi/legacy/results/analysis/2025_1/{PROPOSAL_ID}/energy_scan_results/'
created = False
for i in range(len(RESULT_DIR.split("/"))):
    if not os.path.isdir("/".join(RESULT_DIR.split("/")[:i+1])) and not (i==0 and RESULT_DIR[0]=="/"):
        os.mkdir("/".join(RESULT_DIR.split("/")[:i+1]))
        created = True
if not created:
    print("Results path exists!")
# Out:
#                                                                                        Filename
# 0                            CM_A1_03_2470.00eV_ai4.00_wa18_bpm155.798_id894596_000000_WAXS.tif
# 1     CM_wideincidentanglescan_A1_06_2450.00eV_ai2.300_wa18_bpm156.231_id895729_000000_WAXS.tif
# 2                            CM_A1_06_2478.75eV_ai0.80_wa18_bpm155.389_id895849_000000_WAXS.tif
# 3                            CM_A1_01_2479.50eV_ai0.40_wa18_bpm155.524_id893654_000000_WAXS.tif
# 4                            CM_A1_02_2472.50eV_ai4.00_wa18_bpm155.511_id894179_000000_WAXS.tif
# ...                                                                                         ...
# 2910                         CM_A1_06_2471.75eV_ai4.00_wa18_bpm155.740_id895884_000000_WAXS.tif
# 2911                         CM_A1_06_2471.50eV_ai4.00_wa18_bpm155.763_id895883_000000_WAXS.tif
# 2912  CM_wideincidentanglescan_A1_03_2450.00eV_ai0.260_wa18_bpm156.272_id894329_000000_WAXS.tif
# 2913                         CM_A1_05_2472.50eV_ai4.00_wa18_bpm155.752_id895460_000000_WAXS.tif
# 2914  CM_wideincidentanglescan_A1_05_2450.00eV_ai0.200_wa18_bpm156.092_id895180_000000_WAXS.tif
#
# [2915 rows x 1 columns]
# Results path exists!

# %% [markdown]
# ##### Organise files into sample names and data for each detector angle

# %%
filename_flags: list[str] = ["A1"]
"""The strings you want included in the files processed."""
exclude_flags: list[str] = ['wide', 'calibrationai']
"""The strings you want excluded in the files processed."""

# Find all samples and energies
samples: list[str] = []
"""String names of the unique samples matching patterns in `filename_flags`"""
sample_angles: list[list[float]] = []
"""Unique angles found in the filenames for each sample"""
sample_angle_energies: list[list[list[float]]] = []
"""Unique energies found in the filenames for each sample and angle"""

for file in sorted(os.listdir(RAW_DIR)):
     # Define the flags for the files you want to process, by filtering the filename.
     if all([flag in file for flag in filename_flags] 
            + [flag not in file for flag in exclude_flags]):
        # Find the sample name:
        idx = file.find('_ai')
        sample_substring = file[3:idx-10]
        # If sample substring not in list of samples, add it!
        if sample_substring not in samples:
            sample_idx = len(samples)
            samples.append(sample_substring)
            # Add new lists for the angles and energies
            sample_angles.append([])
            sample_angle_energies.append([])
        else:
            sample_idx = samples.index(sample_substring)
        
        # Find the angle of incidence:
        ai = float(file[idx+3:idx+7])
        if ai not in sample_angles[sample_idx]:
            ai_idx = len(sample_angles[sample_idx])
            sample_angles[sample_idx].append(ai)
            # Add new list for the energies
            sample_angle_energies[sample_idx].append([])
        else:
            ai_idx = sample_angles[sample_idx].index(ai)
        
        # Find the beam energy:
        idx = file.find('eV')
        en = float(file[idx-7:idx])
        if en not in sample_angle_energies[sample_idx][ai_idx]:
            sample_angle_energies[sample_idx][ai_idx].append(en)
    
# Sort the angles and energies
for i in range(len(samples)): 
    for j in range(len(sample_angles[i])):
        # Sort the energies
        sample_angle_energies[i][j] = sorted(sample_angle_energies[i][j])
    # Sort the angles
    args = np.argsort(sample_angles[i])
    sample_angles[i] = np.array(sample_angles[i])[args].tolist()
    sample_angle_energies[i] = np.array(sample_angle_energies[i])[args].tolist()

# Specify the WAXS angles strings to look for, in each sample
WAXS_ANGLE_STRINGS : list[str] = ["wa18"]

# Find all TIF image measurements
datasets: list[list[list[list[str | None]]]] = [[[
                                                [None] * len(WAXS_ANGLE_STRINGS)
                                                for k, _ in enumerate(sample_angle_energies[i][j])]
                                            for j, _ in enumerate(sample_angles[i])]
                                        for i, _ in enumerate(samples)]
"""For each sample, for each angle, for each energy, a list of raw data filenames."""

for i, sample in enumerate(samples):
    for j, file in enumerate(sorted(os.listdir(RAW_DIR))):
        if all([flag in file for flag in filename_flags + [sample, '.tif']] 
                + [flag not in file for flag in exclude_flags]):
            # Check which waxs angle the file is
            ai_idx = file.find('_ai')
            ai = file[ai_idx+3:ai_idx+7]
            en_idx = file.find('eV')
            en = file[en_idx-7:en_idx]
            try:
                angles_idx = sample_angles[i].index(float(ai))
                energies_idx = sample_angle_energies[i][angles_idx].index(float(en))
            except ValueError:
                # Skip incomplete
                continue
            waxs_angle_idx = [k for k, angle in enumerate(WAXS_ANGLE_STRINGS) if angle in file][0]
            datasets[i][angles_idx][energies_idx][waxs_angle_idx] = file

# Display the number of files for each sample:
display(
      pd.DataFrame([
            (sample, np.sum(
                [len(sample_angle_energies[i][j]) * len(WAXS_ANGLE_STRINGS)
                    for j in range(len(sample_angles[i]))]
            ))
            for i, sample in enumerate(samples)
      ], columns=["Sample Name", "Number of Files"])
)
# Out:
#             Sample Name  Number of Files
# 0                 A1_01              252
# 1                 A1_02              252
# 2                 A1_03              252
# 3                 A1_04              252
# 4                 A1_05              252
# 5                 A1_06              252
# 6   fixedpossweep_A1_01               28
# 7   fixedpossweep_A1_02               28
# 8   fixedpossweep_A1_03               28
# 9   fixedpossweep_A1_04               28
# 10  fixedpossweep_A1_05               28
# 11  fixedpossweep_A1_06               28

# %% [markdown]
# ##### Organise the unique energies, and interpolate any missing values for normalisaiton

# %%
global_energies = np.unique([en for sample in sample_angle_energies for angle in sample for en in angle])
if np.all(global_energies != flux_energies):
    print("The flux energies do not match the global energies.")
    print("Generating interpolated values")
    # for i, en in enumerate(global_energies):
    #     if en not in flux_energies:
    #         idx = np.searchsorted(flux_energies, en)
    #         flux_energies.insert(idx, en)
    #         FLUX_NORM[f"ai{ai:0.2f}"][f"ai{ai:0.2f}"][f"ai{ai:0.2f}"][f"ai{ai:0.2f}"][f"ai{ai:0.2f}"][f"ai{ai:0.2f}"]_bpm2 = np.r_[flux_norm_bpm2[:idx], np.interp(en, flux_energies, flux_norm_bpm2), flux_norm_bpm2[idx:]]
    #         flux_norm_bpm3 = np.r_[flux_norm_bpm3[:idx], np.interp(en, flux_energies, flux_norm_bpm3), flux_norm_bpm3[idx:]]
    #         flux_norm_phd = np.r_[flux_norm_phd[:idx], np.interp(en, flux_energies, flux_norm_phd), flux_norm_phd[idx:]]
    #         si0 = np.r_[pixel_summations[:, 0][:idx], np.interp(en, flux_energies, pixel_summations[:, 0]), pixel_summations[:, 0][idx:]]
    #         si20 = np.r_[pixel_summations[:, 1][:idx], np.interp(en, flux_energies, pixel_summations[:, 1]), pixel_summations[:, 1][idx:]]
    #         si_ave = np.r_[si_ave[:idx], np.interp(en, flux_energies, si_ave), si_ave[idx:]]
            
    #         # Re-assign new objects
    #         FLUX_OPTIONS = {
    #             'bpm2': flux_norm_bpm2,
    #             'bpm3': flux_norm_bpm3,
    #             'phd': flux_norm_phd,
    #             'si0': si0,
    #             'si20': si20,
    #             'si_ave': si_ave
    #         }

# %% [markdown]
# # Reduction
# ### Run the first sample to check everything is working and define the Q fit ranges
#
# ##### First check sample image exists and looks reasonable!

# %%
test_files: list[int] = [#0, 20, 40, -2]
                         0, -2]
"""The index of each sample's test file"""
# Out:
# "The index of each sample's test file"

# %%
for i, sample in enumerate(samples):
    for j, ai in enumerate(sample_angles[i]):
        if not (i == 0 or j == 0):
            continue
        for test_file in test_files:
            print(sample, "|", datasets[i][j][test_file][0].replace(sample, ""))
            fig,ax = plt.subplots(len(WAXS_ANGLE_STRINGS),2, figsize=(8,len(WAXS_ANGLE_STRINGS)*1.5), sharex=True, sharey=True)
            for k, angle in enumerate(WAXS_ANGLE_STRINGS):
                fname = datasets[i][j][test_file][k]
                # fig.suptitle(sample)
                # Use 
                img=fabio.open(os.path.join(RAW_DIR, fname)).data
                a = ax[k][0] if len(WAXS_ANGLE_STRINGS) > 1 else ax[0]
                mappable = a.imshow(img, vmin=0, vmax=np.percentile(img,99))
                a.set_title(f"Raw Data ({angle})")
                plt.colorbar(mappable)
                
                # Show the masks on the flatfield image
                a = ax[k][1] if len(WAXS_ANGLE_STRINGS) > 1 else ax[1]
                cmap = mplc.LinearSegmentedColormap.from_list("Mask", [(256,0,0,0),(256,0,0,256)], N=2)
                ff_im_masked = a.imshow(img, interpolation='nearest',
                                        vmin = 0, vmax = np.percentile(img, 99))
                a.imshow(np.rot90(joined_mask,3), cmap=cmap, interpolation='nearest')
                a.set_title("Masked by flatfield and detector")
                plt.colorbar(ff_im_masked)

                if k !=0:
                    break
        
            
            fig.tight_layout()
            plt.show()
        print("------------------------------")
        if j!=0:
            break
    if i!=0:
        break
# Out:
# A1_05 | CM__2445.00eV_ai0.40_wa18_bpm156.017_id895319_000000_WAXS.tif
# A1_05 | CM_fixedpossweep__2540.00eV_ai0.40_wa18_bpm155.253_id895157_000000_WAXS.tif
# ------------------------------
# A1_05 | CM__2445.00eV_ai0.80_wa18_bpm156.230_id895382_000000_WAXS.tif
# A1_05 | CM_fixedpossweep__2540.00eV_ai0.80_wa18_bpm155.248_id895164_000000_WAXS.tif
# ------------------------------
# fixedpossweep_A1_05 | CM__2450.00eV_ai0.40_wa18_bpm156.269_id895152_000000_WAXS.tif
# fixedpossweep_A1_05 | CM__2510.00eV_ai0.40_wa18_bpm155.209_id895156_000000_WAXS.tif
# ------------------------------

# %%
## Note: Tried digging into SMI_beamline > SMI_geometry > stitching_data > stitch.stitching, to understand how the mask is stitched. 
## Too difficult to follow, for some reason mask is not really applied well in the first sector of the detector.
import datetime

for i, sample in enumerate(samples):
    # At each sample, reset the SMI_waxs object
    if SMI_waxs is not None and len(SMI_waxs.ai) != 0:
        # for ai in SMI_waxs.ai:
        #     ai.reset()
        SMI_waxs.ai = []
    
    for j, ai in enumerate(sample_angles[i]):
        if not (i == 0 and j == 2):
            continue
        for test_file in test_files:
            # Setup a figure and open the file
            fig,ax = plt.subplots(1,3, figsize=(12,2.5), sharex=True, sharey=True)
            fnames = datasets[i][j][test_file]
            fname = fnames[0]
            
            # Collect the metadata
            en_idx = fname.find('eV_')
            en = float(fname[en_idx-7:en_idx])
            ai_idx = fname.find("_ai")
            ai2 = float(fname[ai_idx+3:ai_idx+7])
            assert(ai == ai2)
            
            display(pd.DataFrame([
                    (fname, en, ai)
                    ], columns=["Filename", "Energy (eV)", "Incident Angle (deg)"]))
            
            # if i == 0 and j == 0 and (test_file == test_files[0] or test_file == test_files[1]):
            #     print(SMI_waxs.ai)
            
            # Update the geometry/'
            tinit = datetime.datetime.now()
            SMI_waxs.alphai = ai
            tfin = datetime.datetime.now()
            print(f"Time to update geometry: {tfin-tinit}")
            
            tinit = datetime.datetime.now()
            SMI_waxs.wav = en2wav(en)
            tfin = datetime.datetime.now()
            print(f"Time to update wavelength: {tfin-tinit}")
            
            # if i == 0 and j == 0 and (test_file == test_files[0] or test_file == test_files[1]):
            #     print(SMI_waxs.ai)
            
            # Reset the masks
            for mask in SMI_waxs.masks:
                mask[:,:] = False
            
            # Plot the unmodified data
            SMI_waxs.open_data(RAW_DIR, fnames)
            
            SMI_waxs.stitching_data(interp_factor=2, flag_scale=True, timing=True if i==0 and j==0 else False, perpendicular=True)
            # mp = ax[0].imshow(SMI_waxs.img_st,
            #         extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
            mp = ax[0].imshow(SMI_waxs.img_st,
                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
                    # vmin=0,
                    vmax=np.percentile(SMI_waxs.img_st, 99)
            )
            plt.colorbar(mp)
            ax[0].set_title("Stitched Data (Raw)")
            
            # Plot the flatfield / masked normalized data
            SMI_waxs.open_data(RAW_DIR, fnames)
            apply_detector_mask(SMI_waxs)
            # apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE)
            apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE, outliers=False)
            # apply_detector_mask(SMI_waxs)
            
            SMI_waxs.stitching_data(interp_factor=1, flag_scale=True, perpendicular=True)
            # mp = ax[1].imshow(SMI_waxs.img_st,
                    # extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
            mp = ax[1].imshow(SMI_waxs.img_st,
                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
                    # vmin=np.percentile(SMI_waxs.img_st, 1.0), 
                    vmax=np.percentile(SMI_waxs.img_st, 99.0)
            )
            plt.colorbar(mp)
            ax[1].set_title("Stitched (Norm. + Custom Masked)")
            
            # Show the total mask over the image
            cmap = mplc.LinearSegmentedColormap.from_list("Mask", [(256,0,0,0),(256,0,0,256)], N=2)
            mp = ax[2].imshow(SMI_waxs.img_st,
                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
                    # vmin=np.percentile(SMI_waxs.img_st, 1.0), 
                    vmax=np.percentile(SMI_waxs.img_st, 99.0)
            )
            ax[2].imshow(SMI_waxs.mask_st,
                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1],],
                    cmap=cmap
            )
            plt.colorbar(mp)
            ax[2].set_title("Detector mask + custom mask")
            plt.show()
        if i!=0:
            break
# Out:
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_05_2445.00eV_ai4.00_wa18_bpm156.136_id895445_000000_WAXS.tif       2445.0                   4.0
# Time to update geometry: 0:00:00.000003
# Time to update wavelength: 0:00:00.000003
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_05_2540.00eV_ai4.00_wa18_bpm155.219_id895171_000000_WAXS.tif       2540.0                   4.0
# Time to update geometry: 0:00:00.000005
# Time to update wavelength: 0:00:00.672932

# %% [markdown]
# ##### Generate a ROI to check the beam-centre
# ###### Also check that the beamcentre is correct by symmetry (unless sample has anisotropic behavour)

# %%
# Define the radial angles
AZIMUTHAL_WIDTH = 10
"""The +- azimuthal width of the orthogonal range"""
AZIMUTHAL_INPLANE = 10
"""The azimuthal angle for the in-plane scattering"""
AZIMUTHAL_OUTOFPLANE = 80
"""The azimuthal angle for the out-of-plane averaging"""
RADIAL_WIDTH = 35
"""The +- azimuthal width for the radial averaging"""
AZIMUTHAL_RADIAL = 45
"""The azimuthal angle for the radial averaging"""
# Out:
# 'The azimuthal angle for the radial averaging'

# %%
for i, sample in enumerate(samples):
    for j, ai in enumerate(sample_angles[i]):
        if not (i==0 or j==0):
            continue
        for test_file in test_files:
            # Setup a figure and open the file
            fnames = datasets[i][j][test_file]
            if None in fnames:
                print(f"Skipping {sample} due to missing files.")
                continue
            fname = fnames[0]
            
            # Collect the metadata
            en_idx = fname.find('eV_')
            en = float(fname[en_idx-7:en_idx])
            ai_idx = fname.find("_ai")
            ai2 = float(fname[ai_idx+3:ai_idx+7])
            assert(ai==ai2)
            display(pd.DataFrame([
                    (fname, en, ai)
                    ], columns=["Filename", "Energy (eV)", "Incident Angle (deg)"]))
            
            # Update the geometry
            SMI_waxs.alphai = ai
            SMI_waxs.wav = en2wav(en)

            # Show the angles on a plot
            fig,ax = plt.subplots(1,1, figsize=(8,4), sharex=True, sharey=True)

            SMI_waxs.open_data(RAW_DIR, fnames)
            apply_detector_mask(SMI_waxs)
            apply_flatfield(SMI_waxs, flatfield)
            energies_idx = flux_energies.index(en) # for normalisation
            for img in SMI_waxs.imgs:
                if ai == 4.0:
                    img[:] = (img[:] / FLUX_NORM[f"ai{8.0:0.2f}"][energies_idx]).astype(np.int32)
                else:
                    img[:] = (img[:] / FLUX_NORM[f"ai{ai:0.2f}"][energies_idx]).astype(np.int32)
            SMI_waxs.stitching_data(interp_factor=5, flag_scale=True, perpendicular=True)

            ax.set_ylim(SMI_waxs.qz[0], SMI_waxs.qz[-1])
            ax.set_xlim(SMI_waxs.qp[0], SMI_waxs.qp[-1])
            # mp = ax[1].imshow(SMI_waxs.img_st,
                    # extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
            mp = ax.imshow(SMI_waxs.img_st,
                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]], 
                    vmin=np.percentile(SMI_waxs.img_st, 1.0), 
                    vmax=np.percentile(SMI_waxs.img_st, 99.0)
            )
            plt.colorbar(mp)

            # Plot the azimuthal and radial angles
            colors = ['r', 'orange', 'white'][::-1]
            for angle, width in zip([AZIMUTHAL_INPLANE, AZIMUTHAL_OUTOFPLANE, AZIMUTHAL_RADIAL], [AZIMUTHAL_WIDTH, AZIMUTHAL_WIDTH, RADIAL_WIDTH]):
                    # Generate a set of x points to plot lines of.
                    q_x = np.linspace(0, SMI_waxs.qp[-1], 100)
                    # Calculate the x and y gradients for the lines
                    m1 = np.tan(np.deg2rad(angle - width)) if angle - width != 90 else np.inf
                    m2 = np.tan(np.deg2rad(angle + width)) if angle + width != 90 else np.inf
                    # Calculate the x & y values for the lines
                    q_x1 = q_x if m1 != np.inf else np.zeros(100)
                    q_x2 = q_x if m2 != np.inf else np.zeros(100)
                    y1 = m1 * q_x if m1 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                    y2 = m2 * q_x if m2 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                    # Plot the lines
                    color = colors.pop()
                    ax.plot(q_x1, y1, color=color, linestyle='-', label=f"{angle} deg")
                    ax.plot(q_x2, y2, color=color, linestyle='-')
                    # If gradient is inf, calculate an alternative fill between
                    if m2 == np.inf:
                            ax.fill_betweenx(y1, q_x1, q_x2, color=color, alpha=0.1)
                    else:
                            ax.fill_between(q_x, y1, y2, color=color, alpha=0.1)
            ax.legend()
            plt.show()
            # ax.close()
# Out:
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_01_2445.00eV_ai0.40_wa18_bpm156.130_id893611_000000_WAXS.tif       2445.0                   0.4
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2540.00eV_ai0.40_wa18_bpm155.165_id893449_000000_WAXS.tif       2540.0                   0.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 47
#      42 ax.set_xlim(SMI_waxs.qp[0], SMI_waxs.qp[-1])
#      43 # mp = ax[1].imshow(SMI_waxs.img_st,
#      44         # extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]],
#      45 mp = ax.imshow(SMI_waxs.img_st,
#      46         extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]],
# ---> 47         vmin=np.percentile(SMI_waxs.img_st, 1.0),
#      48         vmax=np.percentile(SMI_waxs.img_st, 99.0)
#      49 )
#      50 plt.colorbar(mp)
#      52 # Plot the azimuthal and radial angles
#
# File /nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/numpy/lib/function_base.py:4283, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281 if not _quantile_is_valid(q):
#    4282     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283 return _quantile_unchecked(
#    4284     a, q, axis, out, overwrite_input, method, keepdims)
#
# File /nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/numpy/lib/function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File /nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/numpy/lib/function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File /nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/numpy/lib/function_base.py:4722, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4720     else:
#    4721         arr = a.copy()
# -> 4722 result = _quantile(arr,
#    4723                    quantiles=q,
#    4724                    axis=axis,
#    4725                    method=method,
#    4726                    out=out)
#    4727 return result
#
# File /nsls2/conda/envs/2024-3.0-py312-tiled/lib/python3.12/site-packages/numpy/lib/function_base.py:4824, in _quantile(arr, quantiles, axis, method, out)
#    4820 previous_indexes, next_indexes = _get_indexes(arr,
#    4821                                               virtual_indexes,
#    4822                                               values_count)
#    4823 # --- Sorting
# -> 4824 arr.partition(
#    4825     np.unique(np.concatenate(([0, -1],
#    4826                               previous_indexes.ravel(),
#    4827                               next_indexes.ravel(),
#    4828                               ))),
#    4829     axis=0)
#    4830 if supports_nans:
#    4831     slices_having_nans = np.isnan(arr[-1, ...])
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Calculate the azimuthal/radial averages

# %%
NPOINTS_RADIAL_AVE: int = 2000 # Use a number the is consistent with the pixel density?

# %%
for i, sample in enumerate(samples):
    for j, ai in enumerate(sample_angles[i]):
        if not (i==0 or j==0):
            continue
        
        for test_file in test_files:
            # Setup a figure and open the file
            fnames = datasets[i][j][test_file]
            fname = fnames[0]
            
            # Collect the metadata
            en_idx = fname.find('eV_')
            en = float(fname[en_idx-7:en_idx])
            ai_idx = fname.find("_ai")
            ai2 = float(fname[ai_idx+3:ai_idx+7])
            assert ai==ai2
            display(pd.DataFrame([
                    (fname, en, ai)
                    ], columns=["Filename", "Energy (eV)", "Incident Angle (deg)"]))
            
            # Update the geometry
            tinit = datetime.datetime.now()
            SMI_waxs.alphai = ai
            tfin = datetime.datetime.now()
            print(f"Time to update geometry: {tfin-tinit}")
            
            tinit = datetime.datetime.now()
            SMI_waxs.wav = en2wav(en)
            tfin = datetime.datetime.now()
            print(f"Time to update wavelength: {tfin-tinit}")

            # Open and stitch the data
            tinit = datetime.datetime.now()
            SMI_waxs.open_data(RAW_DIR, fnames)
            tfin = datetime.datetime.now()
            print(f"Time to open data: {tfin-tinit}")
            
            tinit = datetime.datetime.now()
            apply_detector_mask(SMI_waxs)
            apply_flatfield(SMI_waxs, flatfield)
            tfin = datetime.datetime.now()
            print(f"Time to apply masks: {tfin-tinit}")
            
            tinit = datetime.datetime.now()
            energies_idx = flux_energies.index(en) # for normalisation
            for img in SMI_waxs.imgs:
                if ai == 4.0:
                    img[:] = (img[:] / FLUX_NORM[f"ai{8.0:0.2f}"][energies_idx]).astype(np.int32)
                else:
                    img[:] = (img[:] / FLUX_NORM[f"ai{ai:0.2f}"][energies_idx]).astype(np.int32)
            tfin = datetime.datetime.now()
            print(f"Time to normalise data: {tfin-tinit}")
                
            tinit = datetime.datetime.now()
            SMI_waxs.stitching_data(interp_factor=2, flag_scale=False, perpendicular=True)
            tfin = datetime.datetime.now()
            print(f"Time to stitch data: {tfin-tinit}")

            # Generate radial averages
            fig,ax = plt.subplots(2,4, figsize=(12,5), sharex=True, height_ratios=[3,1])
            fig.suptitle(f"{sample}\n{en:0.2f} eV, {ai:0.3f} deg")
            ax[0][0].set_xscale("log")

            tinit = datetime.datetime.now()
            # In plane and out of plane
            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[90 - (AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH) , 90 - (AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_IP, I0_IP, I0_IP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[90 - (AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH), 90 - (AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_OOP, I0_OOP, I0_OOP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

            # Repeat IP and OOP for the consistency checking
            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[-90+(AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH), -90+(AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_IP2, I0_IP2, I0_IP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[-90+(AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH) , -90+(AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_OOP2, I0_OOP2, I0_OOP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

            # Radial averaging
            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[90-(AZIMUTHAL_RADIAL - RADIAL_WIDTH) , -90+(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_R, I0_R, I0_R_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

            # Repeat radial averaging for consistency checking
            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                    azimuth_range=[-90+(AZIMUTHAL_RADIAL - RADIAL_WIDTH) , -90+(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                    npt = NPOINTS_RADIAL_AVE)
            q0_R2, I0_R2, I0_R2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err
            tfin = datetime.datetime.now()
            print(f"Time to radial average: {tfin-tinit}")

            tinit = datetime.datetime.now()
            # Labels
            ax[1][1].set_xlabel("$q$ ($Å^{-1}$)")
            ax[0][0].set_ylabel("Intensity (a.u.)")
            ax[1][0].set_ylabel("Error (Poisson)")
            ax[0][0].set_title("Radial Averaging")
            ax[0][1].set_title("In-plane Averaging")
            ax[0][2].set_title("Out-of-plane Averaging")
            # Plot the radial averages
            ax[0][0].plot(q0_R, I0_R, label="Radial")
            ax[0][0].fill_between(q0_R, I0_R - I0_R_err, I0_R + I0_R_err, alpha=0.5)
            ax[0][0].plot(q0_R2, I0_R2, label="Radial (180)")
            ax[0][0].fill_between(q0_R2, I0_R2 - I0_R2_err, I0_R2 + I0_R2_err, alpha=0.5)
            # Plot the in-plane and out-of-plane averages
            ax[0][1].plot(q0_IP, I0_IP, label="In-plane")
            ax[0][1].fill_between(q0_IP, I0_IP - I0_IP_err, I0_IP + I0_IP_err, alpha=0.5)
            ax[0][1].plot(q0_IP2, I0_IP2, label="In-plane (180)")
            ax[0][1].fill_between(q0_IP2, I0_IP2 - I0_IP2_err, I0_IP2 + I0_IP2_err, alpha=0.5)
            ax[0][2].plot(q0_OOP, I0_OOP, label="Out-of-plane")
            ax[0][2].fill_between(q0_OOP, I0_OOP - I0_OOP_err, I0_OOP + I0_OOP_err, alpha=0.5)
            ax[0][2].plot(q0_OOP2, I0_OOP2, label="Out-of-plane (180)")
            ax[0][2].fill_between(q0_OOP2, I0_OOP2 - I0_OOP2_err, I0_OOP2 + I0_OOP2_err, alpha=0.5)
            # Overlap the in-plane and out-of-plane averages to check for consistency
            ax[0][3].plot(q0_IP, I0_IP, label="In-plane")
            ax[0][3].fill_between(q0_IP, I0_IP - I0_IP_err, I0_IP + I0_IP_err, alpha=0.5)
            ax[0][3].plot(q0_OOP, I0_OOP, label="Out-of-plane")
            ax[0][3].fill_between(q0_OOP, I0_OOP - I0_OOP_err, I0_OOP + I0_OOP_err, alpha=0.5)
            ax[0][3].plot(q0_IP2, I0_IP2, label="In-plane (180)")
            ax[0][3].fill_between(q0_IP2, I0_IP2 - I0_IP2_err, I0_IP2 + I0_IP2_err, alpha=0.5)
            ax[0][3].plot(q0_OOP2, I0_OOP2, label="Out-of-plane (180)")
            ax[0][3].fill_between(q0_OOP2, I0_OOP2 - I0_OOP2_err, I0_OOP2 + I0_OOP2_err, alpha=0.5)

            # Plot the errors
            ax[1][0].plot(q0_R, I0_R_err, label="Radial")
            ax[1][0].plot(q0_R2, I0_R2_err, label="Radial (180)")
            ax[1][1].plot(q0_IP, I0_IP_err, label="In-plane")
            ax[1][1].plot(q0_IP2, I0_IP2_err, label="In-plane (180)")
            ax[1][2].plot(q0_OOP, I0_OOP_err, label="Out-of-plane")
            ax[1][2].plot(q0_OOP2, I0_OOP2_err, label="Out-of-plane (180)")
            ax[1][3].plot(q0_IP, I0_IP_err, label="In-plane")
            ax[1][3].plot(q0_OOP, I0_OOP_err, label="Out-of-plane")
            ax[1][3].plot(q0_IP2, I0_IP2_err, label="In-plane (180)")
            ax[1][3].plot(q0_OOP2, I0_OOP2_err, label="Out-of-plane (180)")

            for a in ax[0]:
                a.legend()
            for a in ax.flatten():
                a.set_yscale("log")
            fig.tight_layout()
            plt.show()
            tfin = datetime.datetime.now()
            print(f"Time to plot: {tfin-tinit}")
            # plt.close()
# Out:
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_01_2445.00eV_ai0.40_wa18_bpm156.130_id893611_000000_WAXS.tif       2445.0                   0.4
# Time to update geometry: 0:00:00.000004
# Time to update wavelength: 0:00:00.367324
# Time to open data: 0:00:00.004540
# Time to apply masks: 0:00:00.010742
# Time to normalise data: 0:00:00.000960
# Time to stitch data: 0:00:04.612087
# Time to radial average: 0:00:12.721416
# Time to plot: 0:00:01.056474
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2540.00eV_ai0.40_wa18_bpm155.165_id893449_000000_WAXS.tif       2540.0                   0.4
# Time to update geometry: 0:00:00.000005
# Time to update wavelength: 0:00:00.427382
# Time to open data: 0:00:00.003947
# Time to apply masks: 0:00:00.011149
# Time to normalise data: 0:00:00.001032
# Time to stitch data: 0:00:04.705137
# Time to radial average: 0:00:12.509309
# Time to plot: 0:00:00.848377
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_01_2445.00eV_ai0.80_wa18_bpm156.163_id893674_000000_WAXS.tif       2445.0                   0.8
# Time to update geometry: 0:00:00.631744
# Time to update wavelength: 0:00:00.472399
# Time to open data: 0:00:00.005950
# Time to apply masks: 0:00:00.012805
# Time to normalise data: 0:00:00.000972
# Time to stitch data: 0:00:05.565068
# Time to radial average: 0:00:12.446139
# Time to plot: 0:00:00.944473
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2540.00eV_ai0.80_wa18_bpm155.212_id893456_000000_WAXS.tif       2540.0                   0.8
# Time to update geometry: 0:00:00.000005
# Time to update wavelength: 0:00:00.499959
# Time to open data: 0:00:00.006178
# Time to apply masks: 0:00:00.019138
# Time to normalise data: 0:00:00.001495
# Time to stitch data: 0:00:05.793199
# Time to radial average: 0:00:12.366961
# Time to plot: 0:00:00.819201
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_01_2445.00eV_ai4.00_wa18_bpm156.244_id893737_000000_WAXS.tif       2445.0                   4.0
# Time to update geometry: 0:00:00.613851
# Time to update wavelength: 0:00:00.547040
# Time to open data: 0:00:00.005143
# Time to apply masks: 0:00:00.013917
# Time to normalise data: 0:00:00.001743
# Time to stitch data: 0:00:05.551241
# Time to radial average: 0:00:12.248027
# Time to plot: 0:00:01.010326
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2540.00eV_ai4.00_wa18_bpm155.163_id893463_000000_WAXS.tif       2540.0                   4.0
# Time to update geometry: 0:00:00.000003
# Time to update wavelength: 0:00:00.493343
# Time to open data: 0:00:00.004387
# Time to apply masks: 0:00:00.012919
# Time to normalise data: 0:00:00.001011
# Time to stitch data: 0:00:05.697225
# Time to radial average: 0:00:12.352973
# Time to plot: 0:00:00.906682
#                                                              Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_A1_01_2445.00eV_ai8.00_wa18_bpm156.265_id893800_000000_WAXS.tif       2445.0                   8.0
# Time to update geometry: 0:00:00.682450
# Time to update wavelength: 0:00:00.478471
# Time to open data: 0:00:00.005684
# Time to apply masks: 0:00:00.012756
# Time to normalise data: 0:00:00.001355
# Time to stitch data: 0:00:06.092015
# Time to radial average: 0:00:13.407446
# Time to plot: 0:00:01.106744
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2540.00eV_ai8.00_wa18_bpm155.255_id893470_000000_WAXS.tif       2540.0                   8.0
# Time to update geometry: 0:00:00.000003
# Time to update wavelength: 0:00:00.517800
# Time to open data: 0:00:00.005645
# Time to apply masks: 0:00:00.011401
# Time to normalise data: 0:00:00.001069
# Time to stitch data: 0:00:06.332175
# Time to radial average: 0:00:11.273073
# Time to plot: 0:00:00.917270
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2450.00eV_ai0.40_wa18_bpm156.251_id893444_000000_WAXS.tif       2450.0                   0.4
# Time to update geometry: 0:00:00.341910
# Time to update wavelength: 0:00:00.309401
# Time to open data: 0:00:00.005179
# Time to apply masks: 0:00:00.011032
# Time to normalise data: 0:00:00.000957
# Time to stitch data: 0:00:04.237303
# Time to radial average: 0:00:10.456091
# Time to plot: 0:00:00.824373
#                                                                            Filename  Energy (eV)  Incident Angle (deg)
# 0  CM_fixedpossweep_A1_01_2510.00eV_ai0.40_wa18_bpm155.097_id893448_000000_WAXS.tif       2510.0                   0.4
# Time to update geometry: 0:00:00.000003
# Time to update wavelength: 0:00:00.387776
# Time to open data: 0:00:00.004890
# Time to apply masks: 0:00:00.011267
# Time to normalise data: 0:00:00.000919
# Time to stitch data: 0:00:04.184713
# Time to radial average: 0:00:10.327484
# Time to plot: 0:00:00.800423

# %% [markdown]
# ##### If happy with line profiles above, then generate the line profiles for test_data.

# %%
OVERRIDE: bool = True
"""Whether to override the analysis reduction or not."""
if not os.path.isdir(RESULT_DIR):
    os.mkdir(RESULT_DIR)
with tqdm.notebook.tqdm(total=len(samples), position=2, leave=True, desc="Samples") as pbar:
    for i, sample in enumerate(samples):
        with tqdm.notebook.tqdm(total=len(sample_angles[i]), position=1, leave=False, desc="Angles") as pbar1:
            for j, ai in enumerate(sample_angles[i]):
                # For each file in the sample
                with tqdm.notebook.tqdm(total=len(test_files), position=0, leave=False, desc="Files") as pbar2:
                    for test_file in test_files:
                        ## Create the results directory for the sample
                        sample_dir = os.path.join(RESULT_DIR, sample)
                        if not os.path.isdir(sample_dir):
                            os.mkdir(sample_dir)
                            
                        ## Create the directories for the images and line profiles
                        giwaxs_img_dir = os.path.join(sample_dir, "giwaxs_flatfielded_images")
                        if not os.path.isdir(giwaxs_img_dir):
                            os.mkdir(giwaxs_img_dir)
                        line_profiles_dir = os.path.join(sample_dir, "line_profiles")
                        if not os.path.isdir(line_profiles_dir):
                            os.mkdir(line_profiles_dir)
                    
                    
                        for k, fnames in enumerate(datasets[i][j][test_file:test_file+1]):
                            fname = fnames[0]
                            # Collect the metadata
                            en_idx = fname.find('eV_')
                            en = float(fname[en_idx-7:en_idx])
                            ai_idx = fname.find("_ai")
                            ai2 = float(fname[ai_idx+3:ai_idx+7])
                            assert ai==ai2
                            
                            # Generate paths for the output files
                            path_det_img = os.path.join(giwaxs_img_dir, f"{sample}_giwaxs_{ai:0.3f}deg_{en:0.2f}eV.png")
                            path_OOP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_OOP.txt")
                            path_IP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_IP.txt")
                            path_R = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_R.txt")
                            path_det_line_profiles_img = os.path.join(sample_dir, f"{sample}_line_profile_angles_test.png")
                            
                            # Do not override the files if they "all" exist already. Override partial file sets though.
                            if (not OVERRIDE 
                                and os.path.isfile(path_det_img) 
                                and os.path.isfile(path_OOP) 
                                and os.path.isfile(path_IP) 
                                and os.path.isfile(path_R)
                                and (k != 0 or os.path.isfile(path_det_line_profiles_img))):
                                pbar.total -= 1
                                continue
                            
                            # Update the geometry
                            SMI_waxs.alphai = ai
                            SMI_waxs.wav = en2wav(en)
                            
                            # Plot the flatfield / masked normalized data
                            SMI_waxs.open_data(RAW_DIR, fnames)
                            apply_detector_mask(SMI_waxs)
                            apply_flatfield(SMI_waxs, flatfield)
                            energies_idx = flux_energies.index(en) # for normalisation
                            for img in SMI_waxs.imgs:
                                 pass
                                # img[:] = (img[:] / FLUX_NORM[f"ai{ai:0.2f}"][energies_idx]).astype(np.int32)
                            SMI_waxs.stitching_data(interp_factor=2, flag_scale=False, perpendicular=True)
                            
                            # Setup a figure and open the file
                            fig,ax = plt.subplots(1,1, figsize=(7, 10), dpi=300)
                            mp = ax.imshow(SMI_waxs.img_st,
                                    extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]],
                                    vmin=np.percentile(SMI_waxs.img_st, 1.0), 
                                    vmax=np.percentile(SMI_waxs.img_st, 99.0) # Avoid extremities
                            )
                            plt.colorbar(mp)
                            ax.set_title(f"{sample}\n{en} eV - {ai} deg")
                            # Don't save the image, as we use a different display format later.
                            # fig.savefig(path_det_img)
                            
                            if k==0:
                                # Plot the azimuthal and radial angles
                                colors = ['r', 'orange', 'white'][::-1]
                                for angle, width in zip([AZIMUTHAL_INPLANE, AZIMUTHAL_OUTOFPLANE, AZIMUTHAL_RADIAL], [AZIMUTHAL_WIDTH, AZIMUTHAL_WIDTH, RADIAL_WIDTH]):
                                    # Generate a set of x points to plot lines of.
                                    q_x = np.linspace(0, SMI_waxs.qp[-1], 100)
                                    # Calculate the x and y gradients for the lines
                                    m1 = np.tan(np.deg2rad(angle - width)) if angle - width != 90 else np.inf
                                    m2 = np.tan(np.deg2rad(angle + width)) if angle + width != 90 else np.inf
                                    # Calculate the x & y values for the lines
                                    q_x1 = q_x if m1 != np.inf else np.zeros(100)
                                    q_x2 = q_x if m2 != np.inf else np.zeros(100)
                                    y1 = m1 * q_x if m1 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                                    y2 = m2 * q_x if m2 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                                    # Plot the lines
                                    color = colors.pop()
                                    ax.plot(q_x1, y1, color=color, linestyle='-', label=f"{angle} deg")
                                    ax.plot(q_x2, y2, color=color, linestyle='-')
                                    # If gradient is inf, calculate an alternative fill between
                                    if m2 == np.inf:
                                            ax.fill_betweenx(y1, q_x1, q_x2, color=color, alpha=0.1)
                                    else:
                                            ax.fill_between(q_x, y1, y2, color=color, alpha=0.1)
                                ax.set_xlim(*SMI_waxs.qp)
                                ax.set_ylim(*SMI_waxs.qz)
                                ax.legend()
                                fig.savefig(path_det_line_profiles_img, dpi=300)
                            plt.close() # Save memory
                            
                            # Perform the radial/azimuthal averaging
                            # In plane and out of plane
                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[90 - (AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH) , 90 - (AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_IP, I0_IP, I0_IP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[90 - (AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH), 90 - (AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_OOP, I0_OOP, I0_OOP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                            # Repeat IP and OOP for the consistency checking
                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[-90+(AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH), -90+(AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_IP2, I0_IP2, I0_IP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[-90+(AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH) , -90+(AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_OOP2, I0_OOP2, I0_OOP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                            # Radial averaging
                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[90-(AZIMUTHAL_RADIAL - RADIAL_WIDTH), 90-(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_R, I0_R, I0_R_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                            # Repeat radial averaging for consistency checking
                            SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                    azimuth_range=[-90+(AZIMUTHAL_RADIAL - RADIAL_WIDTH), -90+(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                                    npt = NPOINTS_RADIAL_AVE)
                            q0_R2, I0_R2, I0_R2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err
                            
                            # Save the line profiles 
                            header = ("Main Data\t\tMirror-Y axis Data\t\n" 
                                    + "q (Å^-1)\tI (a.u.)\tI_err (a.u.)\tq (Å^-1)\tI (a.u.)\tI_err (a.u.)\n")
                            delim = "\t"
                            kwargs = {"header": header, "delimiter": delim}
                            np.savetxt(path_OOP, np.array([q0_OOP, I0_OOP, I0_OOP_err, q0_OOP2, I0_OOP2, I0_OOP2_err]).T, **kwargs)
                            np.savetxt(path_IP, np.array([q0_IP, I0_IP, I0_IP_err, q0_IP2, I0_IP2, I0_IP2_err]).T, **kwargs)
                            np.savetxt(path_R, np.array([q0_R, I0_R, I0_R_err, q0_R2, I0_R2, I0_R2_err]).T, **kwargs)
                            
                            # Update the progress bars
                            pbar2.update(1)
                pbar1.update(1)
        pbar.update(1)
# Out:
# Samples:   0%|          | 0/2 [00:00<?, ?it/s]
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Files:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ##### Using example data, define regions for fluorescence collection in the radial scan

# %%
FLUOR_RANGE: tuple[float, float] = (0.8, 0.92)
"""Q-range for the fluorescence signal summation; define in a flat region away from any peaks/features!"""

# Plot the example data, and plot the fluorescence signal
fig: plt.Figure
ax: list[plt.Axes]
fig,ax = plt.subplots(1,2, figsize=(12,5))
for i, sample in enumerate(samples):
    sample_dir = os.path.join(RESULT_DIR, sample)
    line_profiles_dir = os.path.join(sample_dir, "line_profiles")
    for j, ai in enumerate(sample_angles[i]):
        test_dataset = [datasets[i][j][test_file] for test_file in test_files]
        # Gather the fluor data
        fluor_data = np.zeros((len(test_dataset), 3)) # en, I, I_err
        for k, fnames in enumerate(test_dataset):
            ## Create the results directory for the sample
            fname = fnames[0]
            # Collect the metadata
            en_idx = fname.find('eV_')
            en = float(fname[en_idx-7:en_idx])
            ai_idx = fname.find("_ai")
            ai = float(fname[ai_idx+3:ai_idx+7])
            # Generate paths for the output files
            path_R = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_R.txt")

            # Load the data
            data = np.loadtxt(path_R, skiprows=3, delimiter="\t")
            q = data[:,0]
            I = data[:,1]
            I_err = data[:,2]
            
            # Find the fluorescence signal
            mask = (q > FLUOR_RANGE[0]) & (q < FLUOR_RANGE[1])
            fluor_data[k, 0] = en
            fluor_data[k, 1] = np.trapz(I[mask], q[mask])
            fluor_data[k, 2] = np.trapz(I_err[mask], q[mask])
            
            # Plot the data
            ax[0].plot(q, I, label=f"{en} eV, {ai} deg")
            
        ax[1].plot(fluor_data[:,0], fluor_data[:,1], label=f"{sample} {ai}")
        ax[1].fill_between(fluor_data[:,0], fluor_data[:,1] - fluor_data[:,2], fluor_data[:,1] + fluor_data[:,2], alpha=0.5)
    
# ax[0].axvspan(*FLUOR_RANGE, color="gray", alpha=0.5)
ax[0].set_xlabel("q (Å$^{-1}$)")
ax[0].set_ylabel("Intensity (a.u.)")
ax[0].set_title("Radial Averaging")
ax[0].set_yscale("log")
# ax[0].legend()
ax[1].set_xlabel("Energy (eV)")
ax[1].set_ylabel("Fluorescence Signal (a.u.)")
ax[1].legend()

# %% [markdown]
# ### Detector images and consequent line profile reduction
# ##### Create a plotting function

# %%
MIN_E: float = 2440.0
MAX_E: float = 2560.0

def generate_energy_video_figure(geom: SMI_beamline.SMI_geometry, 
                              dataset_minimum:float, 
                              dataset_maximum: float, 
                              en: float) -> plt.Figure:
    SMI_waxs = geom
    if len(SMI_waxs.imgs) == 3:
        # Works for single detector plots
        figsize = (4,5) 
    else:
        # Works for 0, 20  deg detector angles... generic?
        qp = SMI_waxs.qp
        qz = SMI_waxs.qz
        qp_diff = qp[0] - qp[1]
        qz_diff = qz[0] - qz[1]
        qmax = np.max([qp_diff, qz_diff])
        scale = 4
        figsize = (qp_diff/qmax * scale * 1.02, qz_diff/qmax * scale)
    
    fig = plt.figure(figsize = figsize, dpi=150)
    gs = fig.add_gridspec(2,2, width_ratios=[1,0.05], height_ratios=[1, 0.05])
    ax = fig.add_subplot(gs[0,0])
    ax_cmap = fig.add_subplot(gs[0,1])
    ax_ai = fig.add_subplot(gs[1,0])

    cmap = plt.get_cmap('terrain')
    norm = mplc.LogNorm(vmin=dataset_minimum, vmax=dataset_maximum, clip=True)
    mp = ax.matshow(SMI_waxs.img_st,
            extent=[SMI_waxs.qp[0], SMI_waxs.qp[-1], SMI_waxs.qz[0], SMI_waxs.qz[-1]],
            cmap = cmap,
            norm=norm
    )
    colorbar = fig.colorbar(mp, cax=ax_cmap, orientation='vertical', location="right", fraction = 0.05)
    colorbar.ax.set_ylabel("Intensity (a.u.)", fontsize=4)
    colorbar.ax.tick_params(axis='both', which='major', labelsize=4)
    ax.axis('off')

    ax2 = ax_ai
    ax2.yaxis.set_ticks([])
    ax2.set_ylim(0,1)
    ax2.set_xscale("linear")
    ax2.set_xlim(MIN_E, MAX_E)
    ax2.tick_params(axis='both', which='major', labelsize=4)
    ax2.plot([en, en], [0, 1], 'r')
    ax2.set_xlabel(f"Beam Energy     {en:0.3f} eV", loc="left", fontsize=4)

    fig.tight_layout()
    return fig

if "dataset_minimum" in locals():
    plt.ion()
    matplotlib.interactive(True)
    
    SMI_waxs.open_data(RAW_DIR, fnames)
    apply_detector_mask(SMI_waxs)
    apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE)
    energies_idx = flux_energies.index(en) # for normalisation
    for img in SMI_waxs.imgs:
        img[:] = (img[:] / FLUX_NORM[f"ai{ai:0.2f}"][energies_idx]).astype(np.int32)
    SMI_waxs.stitching_data(interp_factor=3, flag_scale=False, perpendicular=True)
    
    fig = generate_energy_video_figure(SMI_waxs, 1, dataset_maximum, en)

# %% [markdown]
# ##### Reduce the lineprofiles and generate fluorescence profiles

# %%
OVERRIDE: bool = False
"""Whether to override the analysis reduction or not."""

STITCH_MINMAX: bool = False
"""Whether to stitch the data to find the minimum and maximum values for the dataset, 
otherwise just use raw values from 2D detector array using fabio."""

# Check the timing performance
timing:bool = False
import datetime
tcheck = datetime.datetime.now()

# Run the script
plt.ioff()
plt.close('all')
matplotlib.interactive(False)
with tqdm.notebook.tqdm(total=len(samples), position=0, leave=True, desc="All Samples") as pbar:
    for i, sample in enumerate(samples):
        ## Create the results directory for the sample
        sample_dir = os.path.join(RESULT_DIR, sample)
        if not os.path.isdir(sample_dir):
            os.mkdir(sample_dir)
            
        ## Create the directories for the images and line profiles
        giwaxs_img_dir = os.path.join(sample_dir, "giwaxs_flatfielded_images")
        if not os.path.isdir(giwaxs_img_dir):
            os.mkdir(giwaxs_img_dir)
        line_profiles_dir = os.path.join(sample_dir, "line_profiles")
        if not os.path.isdir(line_profiles_dir):
            os.mkdir(line_profiles_dir)
            
        with tqdm.notebook.tqdm(total=len(sample_angles[i]), position=1, leave=False, desc="Angles") as pbar1:
            for j, ai in enumerate(sample_angles[i]):
                # Check if dataset is already processed
                processed = True
                if OVERRIDE:
                    processed = False
                else:
                    for k, fnames in enumerate(datasets[i][j]):
                        fname = fnames[0]
                        # Collect the metadata
                        en_idx = fname.find('eV_')
                        en = float(fname[en_idx-7:en_idx])
                        ai_idx = fname.find("_ai")
                        ai2 = float(fname[ai_idx+3:ai_idx+7])
                        assert ai == ai2
                        
                        # Generate paths for the output files
                        path_det_img = os.path.join(giwaxs_img_dir, f"{sample}_giwaxs_{ai:0.3f}deg_{en:0.2f}eV.png")
                        path_OOP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_O{en:0.2f}eV_OP.txt")
                        path_IP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_IP.txt")
                        path_R = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_R.txt")
                        path_det_line_profiles_img = os.path.join(sample_dir, f"{sample}_{ai}deg_line_profile_angles.png")
                        
                        if not all([os.path.isfile(path) for path in [path_det_img, path_OOP, path_IP, path_R, path_det_line_profiles_img]]):
                            processed = False
                            break
                        
                if processed:
                    print(f"Skipping processed dataset for sample {sample} at {en} energy.")
                    pbar1.total -= 1
                    pbar1.update(0)
                    continue

                dataset_maximum = None
                dataset_minimum = None
                with tqdm.notebook.tqdm(total=len(datasets[i][j]), position=2, leave=False, desc="Finding dataset maximum / minimum") as pbar2:
                    for k, fnames in enumerate(datasets[i][j]):
                        fname = fnames[0]
                        # Collect the metadata
                        en_idx = fname.find('eV_')
                        en = float(fname[en_idx-7:en_idx])
                        ai_idx = fname.find("_ai")
                        ai2 = float(fname[ai_idx+3:ai_idx+7])
                        assert ai==ai2
                        if STITCH_MINMAX:
                        
                            # Update the geometry
                            if timing:
                                tcheck = datetime.datetime.now()
                                SMI_waxs.alphai = ai
                                tupdate = datetime.datetime.now()
                                print(f"Time to update geometry: {tupdate - tcheck}")
                                        
                                
                                tcheck = datetime.datetime.now()
                                SMI_waxs.wav = en2wav(en)
                                tupdate = datetime.datetime.now()
                                print(f"Time to update wavelength: {tupdate - tcheck}")
                                
                                # Flatfield / masked normalized data
                                tcheck = datetime.datetime.now()
                                SMI_waxs.open_data(RAW_DIR, fnames)
                                tupdate = datetime.datetime.now()
                                print(f"Time to open data: {tupdate - tcheck}")
                                
                                tcheck = datetime.datetime.now()
                                apply_detector_mask(SMI_waxs)
                                apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE)
                                tupdate = datetime.datetime.now()
                                print(f"Time to apply flatfield and mask: {tupdate - tcheck}")
                                
                                energies_idx = global_energies.tolist().index(en) # for normalisation
                                for img in SMI_waxs.imgs:
                                    img[:] = (img[:] / FLUX_NORM[energies_idx]).astype(np.int32)
                                    # pass
                                    
                                tcheck = datetime.datetime.now()
                                SMI_waxs.stitching_data(interp_factor=3, flag_scale=False, timing=True, perpendicular=True)
                                tupdate = datetime.datetime.now()
                                print(f"Time to stitch data: {tupdate - tcheck}")
                            
                            else:
                                # Unnecessary to set the correct geometry and wavelength for each image when finding min/max
                                # SMI_waxs.alphai = ai
                                # SMI_waxs.wav = en2wav(en)
                                SMI_waxs.open_data(RAW_DIR, fnames)
                                apply_detector_mask(SMI_waxs)
                                apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE)
                                
                                energies_idx = global_energies.tolist().index(en) # for normalisation
                                for img in SMI_waxs.imgs:
                                    img[:] = (img[:] / FLUX_NORM[energies_idx]).astype(np.int32)
                                    # pass
                                SMI_waxs.stitching_data(interp_factor=3, flag_scale=False, perpendicular=True)
                                
                            # Collect the maximum and minimum values
                            if dataset_maximum is None:
                                dataset_maximum = np.max(SMI_waxs.img_st)
                            else:
                                dataset_maximum = np.max([dataset_maximum, np.max(SMI_waxs.img_st)])
                                
                            if dataset_minimum is None:
                                dataset_minimum = np.min(SMI_waxs.img_st[SMI_waxs.img_st > 0])
                            else:
                                min_val = np.min(SMI_waxs.img_st[SMI_waxs.img_st > 0])
                                dataset_minimum = np.min([dataset_minimum, min_val])
                        else:
                            # Open the file using pyFAI
                            for file in fnames:
                                raw_img = fabio.open(os.path.join(RAW_DIR, file)).data
                                if dataset_maximum is None:
                                    dataset_maximum = np.max(raw_img)
                                else:
                                    dataset_maximum = np.max([dataset_maximum, np.max(raw_img)])
                                if dataset_minimum is None:
                                    dataset_minimum = np.min(raw_img[raw_img > 0])
                                else:
                                    min_val = np.min(raw_img[raw_img > 0])
                                    dataset_minimum = np.min([dataset_minimum, min_val])
                        pbar2.update(1)
                
                cmap = plt.get_cmap('viridis')
                norm = mplc.LogNorm(vmin=dataset_minimum, vmax=dataset_maximum)
                
                
                # Gather the fluor data
                fluor_data = np.zeros((len(datasets[i][j]), 3))
                
                # Create paths for fluor figure and data
                path_flour_fig = os.path.join(sample_dir, f"{sample}_{ai}_fluorescence.png")
                path_flour_data = os.path.join(sample_dir, f"{sample}_{ai}_fluorescence_data.txt")
                
                with tqdm.notebook.tqdm(total=len(datasets[i][j]), position=1, leave=False, desc="Sample dataset") as pbar2:
                    # For each file in the sample
                    for k, fnames in enumerate(datasets[i][j]):
                        fname = fnames[0]
                        # Collect the metadata
                        en_idx = fname.find('eV_')
                        en = float(fname[en_idx-7:en_idx])
                        ai_idx = fname.find("_ai")
                        ai2 = float(fname[ai_idx+3:ai_idx+7])
                        assert ai2 == ai
                        
                        # Generate paths for the output files
                        path_det_img = os.path.join(giwaxs_img_dir, f"{sample}_giwaxs_{ai:0.3f}deg_{en:0.2f}eV.png")
                        path_OOP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_OOP.txt")
                        path_IP = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_IP.txt")
                        path_R = os.path.join(line_profiles_dir, f"{sample}_line_profile_{ai:0.3f}deg_{en:0.2f}eV_R.txt")
                        path_det_line_profiles_img = os.path.join(sample_dir, f"{sample}_{ai}deg_line_profile_angles.png")
                        
                        # Do not override the files if they "all" exist already. Override partial file sets though.
                        if (not OVERRIDE 
                            and os.path.isfile(path_det_img) 
                            and os.path.isfile(path_OOP) 
                            and os.path.isfile(path_IP) 
                            and os.path.isfile(path_R)
                            and os.path.isfile(path_flour_fig)
                            and os.path.isfile(path_flour_data)
                            and (k != 0 or os.path.isfile(path_det_line_profiles_img))):
                            pbar2.total -= 1 # Reduce the total count
                            continue
                        
                        # Update the geometry
                        SMI_waxs.alphai = ai
                        SMI_waxs.wav = en2wav(en)
                        
                        # flatfield / masked normalized data
                        SMI_waxs.open_data(RAW_DIR, fnames)
                        apply_detector_mask(SMI_waxs)
                        apply_flatfield(SMI_waxs, flatfield, flat_percentile=FLATFIELD_PERCENTILE, img_percentile=SAMPLE_PERCENTILE)
                        energies_idx = flux_energies.index(en) # for normalisation
                        for img in SMI_waxs.imgs:
                            img[:] = (img[:] / FLUX_NORM[f"ai{ai:0.2f}"][energies_idx]).astype(np.int32)
                            # pass
                        SMI_waxs.stitching_data(interp_factor=2, flag_scale=True, timing= True, perpendicular=True)
                        
                        # Setup a figure and open the file
                        fig = generate_energy_video_figure(SMI_waxs, 1, dataset_maximum, en)
                        fig.savefig(path_det_img)
                        ax = fig.get_axes()[0]
                        
                        if k==0:
                            # Plot the azimuthal and radial angles
                            colors = ['r', 'orange', 'white'][::-1]
                            for angle, width in zip([AZIMUTHAL_INPLANE, AZIMUTHAL_OUTOFPLANE, AZIMUTHAL_RADIAL], [AZIMUTHAL_WIDTH, AZIMUTHAL_WIDTH, RADIAL_WIDTH]):
                                # Generate a set of x points to plot lines of.
                                q_x = np.linspace(0, SMI_waxs.qp[-1], 100)
                                # Calculate the x and y gradients for the lines
                                m1 = np.tan(np.deg2rad(angle - width)) if angle - width != 90 else np.inf
                                m2 = np.tan(np.deg2rad(angle + width)) if angle + width != 90 else np.inf
                                # Calculate the x & y values for the lines
                                q_x1 = q_x if m1 != np.inf else np.zeros(100)
                                q_x2 = q_x if m2 != np.inf else np.zeros(100)
                                y1 = m1 * q_x if m1 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                                y2 = m2 * q_x if m2 != np.inf else np.linspace(0, SMI_waxs.qz[-1], 100)
                                # Plot the lines
                                color = colors.pop()
                                ax.plot(q_x1, y1, color=color, linestyle='-', label=f"{angle} deg")
                                ax.plot(q_x2, y2, color=color, linestyle='-')
                                # If gradient is inf, calculate an alternative fill between
                                if m2 == np.inf:
                                        ax.fill_betweenx(y1, q_x1, q_x2, color=color, alpha=0.1)
                                else:
                                        ax.fill_between(q_x, y1, y2, color=color, alpha=0.1)
                            ax.set_xlim(*SMI_waxs.qp)
                            ax.set_ylim(*SMI_waxs.qz)
                            ax.legend()
                            fig.savefig(path_det_line_profiles_img, dpi=300)
                        plt.close(fig) # Save memory
                        
                        # Perform the radial/azimuthal averaging
                        # In plane and out of plane
                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[90 - (AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH) , 90 - (AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_IP, I0_IP, I0_IP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[90 - (AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH), 90 - (AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_OOP, I0_OOP, I0_OOP_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                        # Repeat IP and OOP for the consistency checking
                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[-90+(AZIMUTHAL_INPLANE - AZIMUTHAL_WIDTH), -90+(AZIMUTHAL_INPLANE + AZIMUTHAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_IP2, I0_IP2, I0_IP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[-90+(AZIMUTHAL_OUTOFPLANE - AZIMUTHAL_WIDTH) , -90+(AZIMUTHAL_OUTOFPLANE + AZIMUTHAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_OOP2, I0_OOP2, I0_OOP2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                        # Radial averaging
                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[90-(AZIMUTHAL_RADIAL - RADIAL_WIDTH), 90-(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_R, I0_R, I0_R_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err

                        # Repeat radial averaging for consistency checking
                        SMI_waxs.radial_averaging(radial_range = [0, 8], 
                                                azimuth_range=[-90+(AZIMUTHAL_RADIAL - RADIAL_WIDTH), -90+(AZIMUTHAL_RADIAL + RADIAL_WIDTH)], 
                                                npt = NPOINTS_RADIAL_AVE)
                        q0_R2, I0_R2, I0_R2_err = SMI_waxs.q_rad, SMI_waxs.I_rad, SMI_waxs.I_rad_err
                        
                        # Save the line profiles 
                        header = ("Main Data\t\tMirror-Y axis Data\t\n" 
                                + "q (Å^-1)\tI (a.u.)\tI_err (a.u.)\tq (Å^-1)\tI (a.u.)\tI_err (a.u.)\n")
                        delim = "\t"
                        kwargs = {"header": header, "delimiter": delim}
                        np.savetxt(path_OOP, np.array([q0_OOP, I0_OOP, I0_OOP_err, q0_OOP2, I0_OOP2, I0_OOP2_err]).T, **kwargs)
                        np.savetxt(path_IP, np.array([q0_IP, I0_IP, I0_IP_err, q0_IP2, I0_IP2, I0_IP2_err]).T, **kwargs)
                        np.savetxt(path_R, np.array([q0_R, I0_R, I0_R_err, q0_R2, I0_R2, I0_R2_err]).T, **kwargs)
                        
                        # Calculate the Fluorescence data
                        mask = (q0_R > FLUOR_RANGE[0]) & (q0_R < FLUOR_RANGE[1])
                        fluor_data[k, 0] = en
                        fluor_data[k, 1] = np.trapz(I0_R[mask], q0_R[mask])
                        fluor_data[k, 2] = np.trapz(I0_R_err[mask], q0_R[mask])
                        
                        
                        pbar2.update(1)
                        plt.close("all")
                        # break # Only do the first file for now.
                
                # Save and plot the Fluroescence data
                idx = np.argsort(fluor_data[:,0]) #sort by energy
                fluor_data = fluor_data[idx]
                if not os.path.isfile(path_flour_data) or OVERRIDE:
                    with open(path_flour_data, "w") as f:
                        f.write("Energy (eV)\tFluorescence (a.u.)\tFluorescence Error (a.u.)\n")
                        np.savetxt(f, fluor_data, delimiter="\t")
                
                if not os.path.isfile(path_flour_fig) or OVERRIDE:
                    fig, ax = plt.subplots(1, 1, figsize=(12, 4))
                    ax.plot(fluor_data[:,0], fluor_data[:,1], label="Fluorescence")
                    ax.fill_between(fluor_data[:,0], fluor_data[:,1] - fluor_data[:,2], fluor_data[:,1] + fluor_data[:,2], alpha=0.5)
                    ax.set_xlabel("Energy (eV)")
                    ax.set_ylabel("Fluorescence (a.u.)")
                    ax.set_title(f"{sample} Fluorescence")
                    fig.tight_layout()
                    fig.savefig(path_flour_fig)
                    plt.close(fig)
                pbar1.update(1)
        pbar.update(1)
# Out:
# All Samples:   0%|          | 0/12 [00:00<?, ?it/s]
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000075
# Time to stitch the images: 0:00:05.109172
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:05.133247
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:04.926728
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.919952
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:04.952523
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:05.143602
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:04.901075
# Time to calc perpendicular geometry: 0:00:00.000061
# Time to stitch the images: 0:00:05.111099
# Time to calc perpendicular geometry: 0:00:00.000067
# Time to stitch the images: 0:00:05.116339
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:05.089012
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.953168
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:04.975728
# Time to calc perpendicular geometry: 0:00:00.000069
# Time to stitch the images: 0:00:04.941443
# Time to calc perpendicular geometry: 0:00:00.000060
# Time to stitch the images: 0:00:04.905366
# Time to calc perpendicular geometry: 0:00:00.000066
# Time to stitch the images: 0:00:04.856334
# Time to calc perpendicular geometry: 0:00:00.000071
# Time to stitch the images: 0:00:05.028808
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:05.008858
# Time to calc perpendicular geometry: 0:00:00.000066
# Time to stitch the images: 0:00:05.234148
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:04.964454
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.958375
# Time to calc perpendicular geometry: 0:00:00.000066
# Time to stitch the images: 0:00:04.862261
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.943462
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.894604
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:05.033491
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:04.943320
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:04.965137
# Time to calc perpendicular geometry: 0:00:00.000066
# Time to stitch the images: 0:00:04.854529
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:05.070196
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:04.897800
# Time to calc perpendicular geometry: 0:00:00.000062
# Time to stitch the images: 0:00:05.009722
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:04.836026
# Time to calc perpendicular geometry: 0:00:00.000066
# Time to stitch the images: 0:00:05.142394
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:04.866625
# Time to calc perpendicular geometry: 0:00:00.000062
# Time to stitch the images: 0:00:04.959958
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:04.898471
# Time to calc perpendicular geometry: 0:00:00.000073
# Time to stitch the images: 0:00:05.020916
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:04.871852
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:05.060720
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:04.922183
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:05.098694
# Time to calc perpendicular geometry: 0:00:00.000072
# Time to stitch the images: 0:00:04.861465
# Time to calc perpendicular geometry: 0:00:00.000071
# Time to stitch the images: 0:00:05.055637
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:05.064313
# Time to calc perpendicular geometry: 0:00:00.000083
# Time to stitch the images: 0:00:05.556471
# Time to calc perpendicular geometry: 0:00:00.000083
# Time to stitch the images: 0:00:05.007960
# Time to calc perpendicular geometry: 0:00:00.000108
# Time to stitch the images: 0:00:06.004258
# Time to calc perpendicular geometry: 0:00:00.000097
# Time to stitch the images: 0:00:06.103551
# Time to calc perpendicular geometry: 0:00:00.000067
# Time to stitch the images: 0:00:05.730782
# Time to calc perpendicular geometry: 0:00:00.000106
# Time to stitch the images: 0:00:06.009855
# Time to calc perpendicular geometry: 0:00:00.000072
# Time to stitch the images: 0:00:05.825287
# Time to calc perpendicular geometry: 0:00:00.000174
# Time to stitch the images: 0:00:05.890858
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:05.742628
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:05.777676
# Time to calc perpendicular geometry: 0:00:00.000196
# Time to stitch the images: 0:00:05.561578
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:06.057938
# Time to calc perpendicular geometry: 0:00:00.000083
# Time to stitch the images: 0:00:05.824320
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:05.898514
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:05.239889
# Time to calc perpendicular geometry: 0:00:00.000072
# Time to stitch the images: 0:00:05.950372
# Time to calc perpendicular geometry: 0:00:00.000101
# Time to stitch the images: 0:00:06.055783
# Time to calc perpendicular geometry: 0:00:00.000067
# Time to stitch the images: 0:00:05.998680
# Time to calc perpendicular geometry: 0:00:00.000090
# Time to stitch the images: 0:00:05.997095
# Time to calc perpendicular geometry: 0:00:00.000069
# Time to stitch the images: 0:00:05.897308
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000094
# Time to stitch the images: 0:00:05.728255
# Time to calc perpendicular geometry: 0:00:00.000069
# Time to stitch the images: 0:00:05.938685
# Time to calc perpendicular geometry: 0:00:00.000065
# Time to stitch the images: 0:00:05.967273
# Time to calc perpendicular geometry: 0:00:00.000054
# Time to stitch the images: 0:00:06.082804
# Time to calc perpendicular geometry: 0:00:00.000064
# Time to stitch the images: 0:00:06.317571
# Time to calc perpendicular geometry: 0:00:00.000075
# Time to stitch the images: 0:00:06.392268
# Time to calc perpendicular geometry: 0:00:00.000089
# Time to stitch the images: 0:00:06.690535
# Time to calc perpendicular geometry: 0:00:00.000101
# Time to stitch the images: 0:00:06.884814
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:06.936547
# Time to calc perpendicular geometry: 0:00:00.000083
# Time to stitch the images: 0:00:06.833010
# Time to calc perpendicular geometry: 0:00:00.000108
# Time to stitch the images: 0:00:06.273781
# Time to calc perpendicular geometry: 0:00:00.000104
# Time to stitch the images: 0:00:06.130044
# Time to calc perpendicular geometry: 0:00:00.000071
# Time to stitch the images: 0:00:06.050600
# Time to calc perpendicular geometry: 0:00:00.000063
# Time to stitch the images: 0:00:06.427576
# Time to calc perpendicular geometry: 0:00:00.000069
# Time to stitch the images: 0:00:06.297186
# Time to calc perpendicular geometry: 0:00:00.000082
# Time to stitch the images: 0:00:06.395862
# Time to calc perpendicular geometry: 0:00:00.000101
# Time to stitch the images: 0:00:06.745279
# Time to calc perpendicular geometry: 0:00:00.000101
# Time to stitch the images: 0:00:09.342389
# Time to calc perpendicular geometry: 0:00:00.000087
# Time to stitch the images: 0:00:07.916306
# Time to calc perpendicular geometry: 0:00:00.000171
# Time to stitch the images: 0:00:09.709357
# Time to calc perpendicular geometry: 0:00:00.000077
# Time to stitch the images: 0:00:07.106586
# Time to calc perpendicular geometry: 0:00:00.000142
# Time to stitch the images: 0:00:08.276380
# Time to calc perpendicular geometry: 0:00:00.000124
# Time to stitch the images: 0:00:07.055205
# Time to calc perpendicular geometry: 0:00:00.000249
# Time to stitch the images: 0:00:08.507152
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:08.098936
# Time to calc perpendicular geometry: 0:00:00.000112
# Time to stitch the images: 0:00:08.473963
# Time to calc perpendicular geometry: 0:00:00.000073
# Time to stitch the images: 0:00:08.876394
# Time to calc perpendicular geometry: 0:00:00.000136
# Time to stitch the images: 0:00:09.685505
# Time to calc perpendicular geometry: 0:00:00.000094
# Time to stitch the images: 0:00:08.903659
# Time to calc perpendicular geometry: 0:00:00.000116
# Time to stitch the images: 0:00:10.095866
# Time to calc perpendicular geometry: 0:00:00.000090
# Time to stitch the images: 0:00:09.439134
# Time to calc perpendicular geometry: 0:00:00.000105
# Time to stitch the images: 0:00:11.374984
# Time to calc perpendicular geometry: 0:00:00.000086
# Time to stitch the images: 0:00:10.629209
# Time to calc perpendicular geometry: 0:00:00.000091
# Time to stitch the images: 0:00:11.013327
# Time to calc perpendicular geometry: 0:00:00.000169
# Time to stitch the images: 0:00:10.025072
# Time to calc perpendicular geometry: 0:00:00.000068
# Time to stitch the images: 0:00:09.885595
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:11.808211
# Time to calc perpendicular geometry: 0:00:00.000140
# Time to stitch the images: 0:00:10.068971
# Time to calc perpendicular geometry: 0:00:00.000190
# Time to stitch the images: 0:00:12.154620
# Time to calc perpendicular geometry: 0:00:00.000117
# Time to stitch the images: 0:00:09.670640
# Time to calc perpendicular geometry: 0:00:00.000114
# Time to stitch the images: 0:00:10.628956
# Time to calc perpendicular geometry: 0:00:00.000137
# Time to stitch the images: 0:00:09.245456
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:11.826912
# Time to calc perpendicular geometry: 0:00:00.000198
# Time to stitch the images: 0:00:10.836736
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:10.726430
# Time to calc perpendicular geometry: 0:00:00.000085
# Time to stitch the images: 0:00:10.924578
# Time to calc perpendicular geometry: 0:00:00.000136
# Time to stitch the images: 0:00:11.063497
# Time to calc perpendicular geometry: 0:00:00.000231
# Time to stitch the images: 0:00:14.734552
# Time to calc perpendicular geometry: 0:00:00.000144
# Time to stitch the images: 0:00:12.730640
# Time to calc perpendicular geometry: 0:00:00.000173
# Time to stitch the images: 0:00:14.384093
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:12.702208
# Time to calc perpendicular geometry: 0:00:00.000095
# Time to stitch the images: 0:00:13.721676
# Time to calc perpendicular geometry: 0:00:00.000375
# Time to stitch the images: 0:00:12.338914
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:13.197644
# Time to calc perpendicular geometry: 0:00:00.000139
# Time to stitch the images: 0:00:12.174917
# Time to calc perpendicular geometry: 0:00:00.000180
# Time to stitch the images: 0:00:10.826952
# Time to calc perpendicular geometry: 0:00:00.000219
# Time to stitch the images: 0:00:13.047514
# Time to calc perpendicular geometry: 0:00:00.000200
# Time to stitch the images: 0:00:11.834308
# Time to calc perpendicular geometry: 0:00:00.000140
# Time to stitch the images: 0:00:13.871491
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:10.542939
# Time to calc perpendicular geometry: 0:00:00.000185
# Time to stitch the images: 0:00:12.587462
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:13.155292
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:12.747897
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000100
# Time to stitch the images: 0:00:11.292390
# Time to calc perpendicular geometry: 0:00:00.000166
# Time to stitch the images: 0:00:10.935545
# Time to calc perpendicular geometry: 0:00:00.000135
# Time to stitch the images: 0:00:10.142328
# Time to calc perpendicular geometry: 0:00:00.000177
# Time to stitch the images: 0:00:11.233597
# Time to calc perpendicular geometry: 0:00:00.000125
# Time to stitch the images: 0:00:09.969147
# Time to calc perpendicular geometry: 0:00:00.000122
# Time to stitch the images: 0:00:10.638610
# Time to calc perpendicular geometry: 0:00:00.000273
# Time to stitch the images: 0:00:10.676500
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:11.866124
# Time to calc perpendicular geometry: 0:00:00.000168
# Time to stitch the images: 0:00:11.339191
# Time to calc perpendicular geometry: 0:00:00.000279
# Time to stitch the images: 0:00:11.706428
# Time to calc perpendicular geometry: 0:00:00.000230
# Time to stitch the images: 0:00:11.154886
# Time to calc perpendicular geometry: 0:00:00.000125
# Time to stitch the images: 0:00:11.006114
# Time to calc perpendicular geometry: 0:00:00.000255
# Time to stitch the images: 0:00:10.329017
# Time to calc perpendicular geometry: 0:00:00.000169
# Time to stitch the images: 0:00:10.651122
# Time to calc perpendicular geometry: 0:00:00.000154
# Time to stitch the images: 0:00:10.749444
# Time to calc perpendicular geometry: 0:00:00.000101
# Time to stitch the images: 0:00:09.440310
# Time to calc perpendicular geometry: 0:00:00.000226
# Time to stitch the images: 0:00:10.045076
# Time to calc perpendicular geometry: 0:00:00.000282
# Time to stitch the images: 0:00:10.930862
# Time to calc perpendicular geometry: 0:00:00.000150
# Time to stitch the images: 0:00:10.808764
# Time to calc perpendicular geometry: 0:00:00.000276
# Time to stitch the images: 0:00:11.508340
# Time to calc perpendicular geometry: 0:00:00.000166
# Time to stitch the images: 0:00:11.381680
# Time to calc perpendicular geometry: 0:00:00.000185
# Time to stitch the images: 0:00:12.098404
# Time to calc perpendicular geometry: 0:00:00.000106
# Time to stitch the images: 0:00:11.853714
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:12.622211
# Time to calc perpendicular geometry: 0:00:00.000095
# Time to stitch the images: 0:00:11.808959
# Time to calc perpendicular geometry: 0:00:00.000116
# Time to stitch the images: 0:00:11.900860
# Time to calc perpendicular geometry: 0:00:00.000109
# Time to stitch the images: 0:00:11.149166
# Time to calc perpendicular geometry: 0:00:00.000246
# Time to stitch the images: 0:00:11.934271
# Time to calc perpendicular geometry: 0:00:00.000209
# Time to stitch the images: 0:00:12.295142
# Time to calc perpendicular geometry: 0:00:00.000193
# Time to stitch the images: 0:00:11.904533
# Time to calc perpendicular geometry: 0:00:00.000162
# Time to stitch the images: 0:00:10.312672
# Time to calc perpendicular geometry: 0:00:00.000174
# Time to stitch the images: 0:00:11.658778
# Time to calc perpendicular geometry: 0:00:00.000131
# Time to stitch the images: 0:00:10.839708
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:10.651178
# Time to calc perpendicular geometry: 0:00:00.000150
# Time to stitch the images: 0:00:10.040777
# Time to calc perpendicular geometry: 0:00:00.000252
# Time to stitch the images: 0:00:08.501539
# Time to calc perpendicular geometry: 0:00:00.000171
# Time to stitch the images: 0:00:10.738564
# Time to calc perpendicular geometry: 0:00:00.000263
# Time to stitch the images: 0:00:11.721738
# Time to calc perpendicular geometry: 0:00:00.000167
# Time to stitch the images: 0:00:12.431973
# Time to calc perpendicular geometry: 0:00:00.000274
# Time to stitch the images: 0:00:13.087833
# Time to calc perpendicular geometry: 0:00:00.000245
# Time to stitch the images: 0:00:12.954082
# Time to calc perpendicular geometry: 0:00:00.000225
# Time to stitch the images: 0:00:13.462384
# Time to calc perpendicular geometry: 0:00:00.000136
# Time to stitch the images: 0:00:13.172953
# Time to calc perpendicular geometry: 0:00:00.000265
# Time to stitch the images: 0:00:14.187954
# Time to calc perpendicular geometry: 0:00:00.000235
# Time to stitch the images: 0:00:13.031156
# Time to calc perpendicular geometry: 0:00:00.000317
# Time to stitch the images: 0:00:11.857650
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:11.317432
# Time to calc perpendicular geometry: 0:00:00.000073
# Time to stitch the images: 0:00:11.897959
# Time to calc perpendicular geometry: 0:00:00.000254
# Time to stitch the images: 0:00:11.610193
# Time to calc perpendicular geometry: 0:00:00.000091
# Time to stitch the images: 0:00:11.981048
# Time to calc perpendicular geometry: 0:00:00.000111
# Time to stitch the images: 0:00:12.620417
# Time to calc perpendicular geometry: 0:00:00.000225
# Time to stitch the images: 0:00:12.896946
# Time to calc perpendicular geometry: 0:00:00.000206
# Time to stitch the images: 0:00:12.377434
# Time to calc perpendicular geometry: 0:00:00.000215
# Time to stitch the images: 0:00:13.846321
# Time to calc perpendicular geometry: 0:00:00.000290
# Time to stitch the images: 0:00:14.029184
# Time to calc perpendicular geometry: 0:00:00.000283
# Time to stitch the images: 0:00:15.060152
# Time to calc perpendicular geometry: 0:00:00.000246
# Time to stitch the images: 0:00:13.961404
# Time to calc perpendicular geometry: 0:00:00.000272
# Time to stitch the images: 0:00:14.456653
# Time to calc perpendicular geometry: 0:00:00.000160
# Time to stitch the images: 0:00:13.095262
# Time to calc perpendicular geometry: 0:00:00.000265
# Time to stitch the images: 0:00:12.920238
# Time to calc perpendicular geometry: 0:00:00.000183
# Time to stitch the images: 0:00:11.835195
# Time to calc perpendicular geometry: 0:00:00.000115
# Time to stitch the images: 0:00:11.436538
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:11.281665
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000235
# Time to stitch the images: 0:00:17.404616
# Time to calc perpendicular geometry: 0:00:00.000214
# Time to stitch the images: 0:00:16.987450
# Time to calc perpendicular geometry: 0:00:00.000150
# Time to stitch the images: 0:00:14.403318
# Time to calc perpendicular geometry: 0:00:00.000118
# Time to stitch the images: 0:00:13.717518
# Time to calc perpendicular geometry: 0:00:00.000181
# Time to stitch the images: 0:00:13.273851
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:14.283141
# Time to calc perpendicular geometry: 0:00:00.000119
# Time to stitch the images: 0:00:13.488273
# Time to calc perpendicular geometry: 0:00:00.000221
# Time to stitch the images: 0:00:13.522865
# Time to calc perpendicular geometry: 0:00:00.000209
# Time to stitch the images: 0:00:12.618975
# Time to calc perpendicular geometry: 0:00:00.000160
# Time to stitch the images: 0:00:12.796752
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:13.213692
# Time to calc perpendicular geometry: 0:00:00.000157
# Time to stitch the images: 0:00:14.333592
# Time to calc perpendicular geometry: 0:00:00.000198
# Time to stitch the images: 0:00:14.865353
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:15.104328
# Time to calc perpendicular geometry: 0:00:00.000294
# Time to stitch the images: 0:00:14.159707
# Time to calc perpendicular geometry: 0:00:00.000152
# Time to stitch the images: 0:00:13.451105
# Time to calc perpendicular geometry: 0:00:00.000088
# Time to stitch the images: 0:00:13.718799
# Time to calc perpendicular geometry: 0:00:00.000144
# Time to stitch the images: 0:00:14.406333
# Time to calc perpendicular geometry: 0:00:00.000176
# Time to stitch the images: 0:00:14.850159
# Time to calc perpendicular geometry: 0:00:00.000180
# Time to stitch the images: 0:00:16.244817
# Time to calc perpendicular geometry: 0:00:00.000233
# Time to stitch the images: 0:00:15.461756
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:15.394630
# Time to calc perpendicular geometry: 0:00:00.000275
# Time to stitch the images: 0:00:13.911589
# Time to calc perpendicular geometry: 0:00:00.000290
# Time to stitch the images: 0:00:14.833917
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:13.337431
# Time to calc perpendicular geometry: 0:00:00.000196
# Time to stitch the images: 0:00:14.232454
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:14.202977
# Time to calc perpendicular geometry: 0:00:00.000320
# Time to stitch the images: 0:00:14.147699
# Time to calc perpendicular geometry: 0:00:00.000135
# Time to stitch the images: 0:00:14.208749
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:15.581396
# Time to calc perpendicular geometry: 0:00:00.000163
# Time to stitch the images: 0:00:16.505199
# Time to calc perpendicular geometry: 0:00:00.000269
# Time to stitch the images: 0:00:17.279535
# Time to calc perpendicular geometry: 0:00:00.000324
# Time to stitch the images: 0:00:16.792375
# Time to calc perpendicular geometry: 0:00:00.000230
# Time to stitch the images: 0:00:17.277055
# Time to calc perpendicular geometry: 0:00:00.000250
# Time to stitch the images: 0:00:16.912682
# Time to calc perpendicular geometry: 0:00:00.000173
# Time to stitch the images: 0:00:17.098439
# Time to calc perpendicular geometry: 0:00:00.000275
# Time to stitch the images: 0:00:15.164341
# Time to calc perpendicular geometry: 0:00:00.000243
# Time to stitch the images: 0:00:14.482196
# Time to calc perpendicular geometry: 0:00:00.000297
# Time to stitch the images: 0:00:13.051537
# Time to calc perpendicular geometry: 0:00:00.000303
# Time to stitch the images: 0:00:12.266894
# Time to calc perpendicular geometry: 0:00:00.000109
# Time to stitch the images: 0:00:11.623342
# Time to calc perpendicular geometry: 0:00:00.000130
# Time to stitch the images: 0:00:12.875264
# Time to calc perpendicular geometry: 0:00:00.000185
# Time to stitch the images: 0:00:12.462976
# Time to calc perpendicular geometry: 0:00:00.000103
# Time to stitch the images: 0:00:13.065294
# Time to calc perpendicular geometry: 0:00:00.000170
# Time to stitch the images: 0:00:13.400011
# Time to calc perpendicular geometry: 0:00:00.000366
# Time to stitch the images: 0:00:14.563245
# Time to calc perpendicular geometry: 0:00:00.000211
# Time to stitch the images: 0:00:15.121013
# Time to calc perpendicular geometry: 0:00:00.000129
# Time to stitch the images: 0:00:14.679775
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:14.912667
# Time to calc perpendicular geometry: 0:00:00.000285
# Time to stitch the images: 0:00:15.869847
# Time to calc perpendicular geometry: 0:00:00.000239
# Time to stitch the images: 0:00:15.494894
# Time to calc perpendicular geometry: 0:00:00.000117
# Time to stitch the images: 0:00:15.056136
# Time to calc perpendicular geometry: 0:00:00.000193
# Time to stitch the images: 0:00:14.092824
# Time to calc perpendicular geometry: 0:00:00.000084
# Time to stitch the images: 0:00:14.681047
# Time to calc perpendicular geometry: 0:00:00.000182
# Time to stitch the images: 0:00:15.558052
# Time to calc perpendicular geometry: 0:00:00.000227
# Time to stitch the images: 0:00:16.283466
# Time to calc perpendicular geometry: 0:00:00.000234
# Time to stitch the images: 0:00:16.093332
# Time to calc perpendicular geometry: 0:00:00.000264
# Time to stitch the images: 0:00:16.885914
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:15.424222
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:15.955814
# Time to calc perpendicular geometry: 0:00:00.000182
# Time to stitch the images: 0:00:15.146583
# Time to calc perpendicular geometry: 0:00:00.000184
# Time to stitch the images: 0:00:14.610882
# Time to calc perpendicular geometry: 0:00:00.000163
# Time to stitch the images: 0:00:13.461519
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000154
# Time to stitch the images: 0:00:12.715785
# Time to calc perpendicular geometry: 0:00:00.000194
# Time to stitch the images: 0:00:13.929423
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:13.521387
# Time to calc perpendicular geometry: 0:00:00.000216
# Time to stitch the images: 0:00:14.406707
# Time to calc perpendicular geometry: 0:00:00.000145
# Time to stitch the images: 0:00:14.504039
# Time to calc perpendicular geometry: 0:00:00.000125
# Time to stitch the images: 0:00:15.837484
# Time to calc perpendicular geometry: 0:00:00.000192
# Time to stitch the images: 0:00:15.403933
# Time to calc perpendicular geometry: 0:00:00.000215
# Time to stitch the images: 0:00:15.122642
# Time to calc perpendicular geometry: 0:00:00.000194
# Time to stitch the images: 0:00:14.010637
# Time to calc perpendicular geometry: 0:00:00.000237
# Time to stitch the images: 0:00:14.904809
# Time to calc perpendicular geometry: 0:00:00.000279
# Time to stitch the images: 0:00:13.218431
# Time to calc perpendicular geometry: 0:00:00.000137
# Time to stitch the images: 0:00:14.222855
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:13.486434
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:14.500138
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:13.992362
# Time to calc perpendicular geometry: 0:00:00.000166
# Time to stitch the images: 0:00:13.966071
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:13.345990
# Time to calc perpendicular geometry: 0:00:00.000164
# Time to stitch the images: 0:00:13.436331
# Time to calc perpendicular geometry: 0:00:00.000277
# Time to stitch the images: 0:00:13.308415
# Time to calc perpendicular geometry: 0:00:00.000279
# Time to stitch the images: 0:00:14.100778
# Time to calc perpendicular geometry: 0:00:00.000224
# Time to stitch the images: 0:00:13.365035
# Time to calc perpendicular geometry: 0:00:00.000276
# Time to stitch the images: 0:00:14.620577
# Time to calc perpendicular geometry: 0:00:00.000163
# Time to stitch the images: 0:00:13.609417
# Time to calc perpendicular geometry: 0:00:00.000128
# Time to stitch the images: 0:00:14.793104
# Time to calc perpendicular geometry: 0:00:00.000133
# Time to stitch the images: 0:00:14.764662
# Time to calc perpendicular geometry: 0:00:00.000206
# Time to stitch the images: 0:00:15.541057
# Time to calc perpendicular geometry: 0:00:00.000235
# Time to stitch the images: 0:00:15.186733
# Time to calc perpendicular geometry: 0:00:00.000205
# Time to stitch the images: 0:00:14.960293
# Time to calc perpendicular geometry: 0:00:00.000246
# Time to stitch the images: 0:00:14.647878
# Time to calc perpendicular geometry: 0:00:00.000228
# Time to stitch the images: 0:00:14.475151
# Time to calc perpendicular geometry: 0:00:00.000159
# Time to stitch the images: 0:00:13.928811
# Time to calc perpendicular geometry: 0:00:00.000218
# Time to stitch the images: 0:00:12.707664
# Time to calc perpendicular geometry: 0:00:00.000126
# Time to stitch the images: 0:00:12.065913
# Time to calc perpendicular geometry: 0:00:00.000141
# Time to stitch the images: 0:00:12.227973
# Time to calc perpendicular geometry: 0:00:00.000108
# Time to stitch the images: 0:00:13.016381
# Time to calc perpendicular geometry: 0:00:00.000189
# Time to stitch the images: 0:00:13.975047
# Time to calc perpendicular geometry: 0:00:00.000193
# Time to stitch the images: 0:00:14.079560
# Time to calc perpendicular geometry: 0:00:00.000171
# Time to stitch the images: 0:00:14.501979
# Time to calc perpendicular geometry: 0:00:00.000151
# Time to stitch the images: 0:00:15.692181
# Time to calc perpendicular geometry: 0:00:00.000091
# Time to stitch the images: 0:00:15.342665
# Time to calc perpendicular geometry: 0:00:00.000325
# Time to stitch the images: 0:00:15.598155
# Time to calc perpendicular geometry: 0:00:00.000190
# Time to stitch the images: 0:00:16.404823
# Time to calc perpendicular geometry: 0:00:00.000316
# Time to stitch the images: 0:00:14.850537
# Time to calc perpendicular geometry: 0:00:00.000177
# Time to stitch the images: 0:00:14.576110
# Time to calc perpendicular geometry: 0:00:00.000123
# Time to stitch the images: 0:00:13.438170
# Time to calc perpendicular geometry: 0:00:00.000253
# Time to stitch the images: 0:00:13.451049
# Time to calc perpendicular geometry: 0:00:00.000309
# Time to stitch the images: 0:00:13.281996
# Time to calc perpendicular geometry: 0:00:00.000142
# Time to stitch the images: 0:00:14.216410
# Time to calc perpendicular geometry: 0:00:00.000250
# Time to stitch the images: 0:00:13.362750
# Time to calc perpendicular geometry: 0:00:00.000141
# Time to stitch the images: 0:00:13.440866
# Time to calc perpendicular geometry: 0:00:00.000195
# Time to stitch the images: 0:00:12.760575
# Time to calc perpendicular geometry: 0:00:00.000246
# Time to stitch the images: 0:00:13.654717
# Time to calc perpendicular geometry: 0:00:00.000169
# Time to stitch the images: 0:00:12.860302
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:13.426198
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:13.809335
# Time to calc perpendicular geometry: 0:00:00.000163
# Time to stitch the images: 0:00:15.036376
# Time to calc perpendicular geometry: 0:00:00.000263
# Time to stitch the images: 0:00:14.823555
# Time to calc perpendicular geometry: 0:00:00.000093
# Time to stitch the images: 0:00:15.829607
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:14.352883
# Time to calc perpendicular geometry: 0:00:00.000125
# Time to stitch the images: 0:00:14.631236
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:15.509123
# Time to calc perpendicular geometry: 0:00:00.000218
# Time to stitch the images: 0:00:16.421282
# Time to calc perpendicular geometry: 0:00:00.000179
# Time to stitch the images: 0:00:16.146501
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000305
# Time to stitch the images: 0:00:15.818458
# Time to calc perpendicular geometry: 0:00:00.000277
# Time to stitch the images: 0:00:14.502625
# Time to calc perpendicular geometry: 0:00:00.000146
# Time to stitch the images: 0:00:14.616667
# Time to calc perpendicular geometry: 0:00:00.000137
# Time to stitch the images: 0:00:14.314796
# Time to calc perpendicular geometry: 0:00:00.000087
# Time to stitch the images: 0:00:13.527840
# Time to calc perpendicular geometry: 0:00:00.000159
# Time to stitch the images: 0:00:14.033047
# Time to calc perpendicular geometry: 0:00:00.000137
# Time to stitch the images: 0:00:15.028882
# Time to calc perpendicular geometry: 0:00:00.000149
# Time to stitch the images: 0:00:14.886311
# Time to calc perpendicular geometry: 0:00:00.000170
# Time to stitch the images: 0:00:14.112113
# Time to calc perpendicular geometry: 0:00:00.000187
# Time to stitch the images: 0:00:12.820183
# Time to calc perpendicular geometry: 0:00:00.000237
# Time to stitch the images: 0:00:11.797388
# Time to calc perpendicular geometry: 0:00:00.000103
# Time to stitch the images: 0:00:11.810475
# Time to calc perpendicular geometry: 0:00:00.000091
# Time to stitch the images: 0:00:11.599153
# Time to calc perpendicular geometry: 0:00:00.000090
# Time to stitch the images: 0:00:12.399646
# Time to calc perpendicular geometry: 0:00:00.000141
# Time to stitch the images: 0:00:13.300454
# Time to calc perpendicular geometry: 0:00:00.000246
# Time to stitch the images: 0:00:13.971921
# Time to calc perpendicular geometry: 0:00:00.000123
# Time to stitch the images: 0:00:13.890910
# Time to calc perpendicular geometry: 0:00:00.000135
# Time to stitch the images: 0:00:13.898420
# Time to calc perpendicular geometry: 0:00:00.000131
# Time to stitch the images: 0:00:14.344304
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:13.282796
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:12.815910
# Time to calc perpendicular geometry: 0:00:00.000218
# Time to stitch the images: 0:00:12.425618
# Time to calc perpendicular geometry: 0:00:00.000097
# Time to stitch the images: 0:00:11.388557
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:12.348746
# Time to calc perpendicular geometry: 0:00:00.000178
# Time to stitch the images: 0:00:12.015419
# Time to calc perpendicular geometry: 0:00:00.000129
# Time to stitch the images: 0:00:11.603140
# Time to calc perpendicular geometry: 0:00:00.000176
# Time to stitch the images: 0:00:11.372090
# Time to calc perpendicular geometry: 0:00:00.000148
# Time to stitch the images: 0:00:11.371109
# Time to calc perpendicular geometry: 0:00:00.000102
# Time to stitch the images: 0:00:10.632558
# Time to calc perpendicular geometry: 0:00:00.000103
# Time to stitch the images: 0:00:11.047407
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:11.403441
# Time to calc perpendicular geometry: 0:00:00.000160
# Time to stitch the images: 0:00:12.159146
# Time to calc perpendicular geometry: 0:00:00.000193
# Time to stitch the images: 0:00:12.377905
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:13.286777
# Time to calc perpendicular geometry: 0:00:00.000120
# Time to stitch the images: 0:00:13.347651
# Time to calc perpendicular geometry: 0:00:00.000141
# Time to stitch the images: 0:00:13.200851
# Time to calc perpendicular geometry: 0:00:00.000156
# Time to stitch the images: 0:00:12.879517
# Time to calc perpendicular geometry: 0:00:00.000263
# Time to stitch the images: 0:00:12.766534
# Time to calc perpendicular geometry: 0:00:00.000233
# Time to stitch the images: 0:00:12.611933
# Time to calc perpendicular geometry: 0:00:00.000125
# Time to stitch the images: 0:00:12.333063
# Time to calc perpendicular geometry: 0:00:00.000183
# Time to stitch the images: 0:00:12.349829
# Time to calc perpendicular geometry: 0:00:00.000178
# Time to stitch the images: 0:00:13.136448
# Time to calc perpendicular geometry: 0:00:00.000104
# Time to stitch the images: 0:00:13.777523
# Time to calc perpendicular geometry: 0:00:00.000079
# Time to stitch the images: 0:00:13.516754
# Time to calc perpendicular geometry: 0:00:00.000243
# Time to stitch the images: 0:00:13.775176
# Time to calc perpendicular geometry: 0:00:00.000136
# Time to stitch the images: 0:00:14.505758
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:15.062313
# Time to calc perpendicular geometry: 0:00:00.000239
# Time to stitch the images: 0:00:15.628769
# Time to calc perpendicular geometry: 0:00:00.000158
# Time to stitch the images: 0:00:15.212409
# Time to calc perpendicular geometry: 0:00:00.000188
# Time to stitch the images: 0:00:14.575934
# Time to calc perpendicular geometry: 0:00:00.000201
# Time to stitch the images: 0:00:14.115505
# Time to calc perpendicular geometry: 0:00:00.000184
# Time to stitch the images: 0:00:14.141747
# Time to calc perpendicular geometry: 0:00:00.000118
# Time to stitch the images: 0:00:13.040037
# Time to calc perpendicular geometry: 0:00:00.000148
# Time to stitch the images: 0:00:12.854490
# Time to calc perpendicular geometry: 0:00:00.000105
# Time to stitch the images: 0:00:13.260335
# Time to calc perpendicular geometry: 0:00:00.000105
# Time to stitch the images: 0:00:14.044927
# Time to calc perpendicular geometry: 0:00:00.000096
# Time to stitch the images: 0:00:14.150766
# Time to calc perpendicular geometry: 0:00:00.000128
# Time to stitch the images: 0:00:14.856273
# Time to calc perpendicular geometry: 0:00:00.000070
# Time to stitch the images: 0:00:15.029109
# Time to calc perpendicular geometry: 0:00:00.000182
# Time to stitch the images: 0:00:15.163271
# Time to calc perpendicular geometry: 0:00:00.000154
# Time to stitch the images: 0:00:14.787835
# Time to calc perpendicular geometry: 0:00:00.000110
# Time to stitch the images: 0:00:14.304784
# Time to calc perpendicular geometry: 0:00:00.000160
# Time to stitch the images: 0:00:13.205883
# Angles:   0%|          | 0/4 [00:00<?, ?it/s]
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000258
# Time to stitch the images: 0:00:09.939301
# Time to calc perpendicular geometry: 0:00:00.000247
# Time to stitch the images: 0:00:11.076353
# Time to calc perpendicular geometry: 0:00:00.000203
# Time to stitch the images: 0:00:10.105276
# Time to calc perpendicular geometry: 0:00:00.000264
# Time to stitch the images: 0:00:11.183477
# Time to calc perpendicular geometry: 0:00:00.000169
# Time to stitch the images: 0:00:10.740801
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:12.003908
# Time to calc perpendicular geometry: 0:00:00.000220
# Time to stitch the images: 0:00:11.879450
# Time to calc perpendicular geometry: 0:00:00.000162
# Time to stitch the images: 0:00:12.799139
# Time to calc perpendicular geometry: 0:00:00.000189
# Time to stitch the images: 0:00:11.475573
# Time to calc perpendicular geometry: 0:00:00.000201
# Time to stitch the images: 0:00:11.825538
# Time to calc perpendicular geometry: 0:00:00.000108
# Time to stitch the images: 0:00:11.606326
# Time to calc perpendicular geometry: 0:00:00.000126
# Time to stitch the images: 0:00:11.174690
# Time to calc perpendicular geometry: 0:00:00.000221
# Time to stitch the images: 0:00:10.640879
# Time to calc perpendicular geometry: 0:00:00.000210
# Time to stitch the images: 0:00:10.581035
# Time to calc perpendicular geometry: 0:00:00.000170
# Time to stitch the images: 0:00:10.234367
# Time to calc perpendicular geometry: 0:00:00.000376
# Time to stitch the images: 0:00:11.308217
# Time to calc perpendicular geometry: 0:00:00.000181
# Time to stitch the images: 0:00:11.522447
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:12.624610
# Time to calc perpendicular geometry: 0:00:00.000180
# Time to stitch the images: 0:00:11.973488
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:11.669334
# Time to calc perpendicular geometry: 0:00:00.000144
# Time to stitch the images: 0:00:11.105744
# Time to calc perpendicular geometry: 0:00:00.000184
# Time to stitch the images: 0:00:10.587195
# Time to calc perpendicular geometry: 0:00:00.000159
# Time to stitch the images: 0:00:10.194048
# Time to calc perpendicular geometry: 0:00:00.000183
# Time to stitch the images: 0:00:10.286116
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:09.264520
# Time to calc perpendicular geometry: 0:00:00.000199
# Time to stitch the images: 0:00:09.540196
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:08.536383
# Time to calc perpendicular geometry: 0:00:00.000062
# Time to stitch the images: 0:00:10.019960
# Time to calc perpendicular geometry: 0:00:00.000211
# Time to stitch the images: 0:00:09.698691
# Time to calc perpendicular geometry: 0:00:00.000260
# Time to stitch the images: 0:00:10.330364
# Time to calc perpendicular geometry: 0:00:00.000120
# Time to stitch the images: 0:00:10.344180
# Time to calc perpendicular geometry: 0:00:00.000227
# Time to stitch the images: 0:00:10.295839
# Time to calc perpendicular geometry: 0:00:00.000253
# Time to stitch the images: 0:00:09.569936
# Time to calc perpendicular geometry: 0:00:00.000293
# Time to stitch the images: 0:00:09.460574
# Time to calc perpendicular geometry: 0:00:00.000156
# Time to stitch the images: 0:00:09.034471
# Time to calc perpendicular geometry: 0:00:00.000258
# Time to stitch the images: 0:00:08.885371
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:08.927895
# Time to calc perpendicular geometry: 0:00:00.000208
# Time to stitch the images: 0:00:09.870043
# Time to calc perpendicular geometry: 0:00:00.000175
# Time to stitch the images: 0:00:09.518113
# Time to calc perpendicular geometry: 0:00:00.000129
# Time to stitch the images: 0:00:10.299831
# Time to calc perpendicular geometry: 0:00:00.000147
# Time to stitch the images: 0:00:10.034623
# Time to calc perpendicular geometry: 0:00:00.000123
# Time to stitch the images: 0:00:10.302858
# Time to calc perpendicular geometry: 0:00:00.000221
# Time to stitch the images: 0:00:09.455524
# Time to calc perpendicular geometry: 0:00:00.000146
# Time to stitch the images: 0:00:10.303296
# Time to calc perpendicular geometry: 0:00:00.000156
# Time to stitch the images: 0:00:09.888119
# Time to calc perpendicular geometry: 0:00:00.000154
# Time to stitch the images: 0:00:10.261879
# Time to calc perpendicular geometry: 0:00:00.000180
# Time to stitch the images: 0:00:09.659261
# Time to calc perpendicular geometry: 0:00:00.000370
# Time to stitch the images: 0:00:09.907637
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:09.079854
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:09.134744
# Time to calc perpendicular geometry: 0:00:00.000224
# Time to stitch the images: 0:00:09.213004
# Time to calc perpendicular geometry: 0:00:00.000148
# Time to stitch the images: 0:00:08.161711
# Time to calc perpendicular geometry: 0:00:00.000106
# Time to stitch the images: 0:00:07.855786
# Time to calc perpendicular geometry: 0:00:00.000231
# Time to stitch the images: 0:00:09.151942
# Time to calc perpendicular geometry: 0:00:00.000138
# Time to stitch the images: 0:00:09.774599
# Time to calc perpendicular geometry: 0:00:00.000144
# Time to stitch the images: 0:00:10.112971
# Time to calc perpendicular geometry: 0:00:00.000206
# Time to stitch the images: 0:00:10.217111
# Time to calc perpendicular geometry: 0:00:00.000119
# Time to stitch the images: 0:00:10.713522
# Time to calc perpendicular geometry: 0:00:00.000092
# Time to stitch the images: 0:00:10.511617
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:10.855230
# Time to calc perpendicular geometry: 0:00:00.000168
# Time to stitch the images: 0:00:10.765414
# Time to calc perpendicular geometry: 0:00:00.000159
# Time to stitch the images: 0:00:10.543734
# Time to calc perpendicular geometry: 0:00:00.000205
# Time to stitch the images: 0:00:09.790953
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:11.005607
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:12.097189
# Time to calc perpendicular geometry: 0:00:00.000128
# Time to stitch the images: 0:00:11.528446
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:12.111159
# Time to calc perpendicular geometry: 0:00:00.000221
# Time to stitch the images: 0:00:11.006194
# Time to calc perpendicular geometry: 0:00:00.000086
# Time to stitch the images: 0:00:10.658938
# Time to calc perpendicular geometry: 0:00:00.000117
# Time to stitch the images: 0:00:10.753238
# Time to calc perpendicular geometry: 0:00:00.000134
# Time to stitch the images: 0:00:11.674437
# Time to calc perpendicular geometry: 0:00:00.000150
# Time to stitch the images: 0:00:11.977112
# Time to calc perpendicular geometry: 0:00:00.000263
# Time to stitch the images: 0:00:12.517891
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:12.023736
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:11.303779
# Time to calc perpendicular geometry: 0:00:00.000158
# Time to stitch the images: 0:00:11.468972
# Time to calc perpendicular geometry: 0:00:00.000161
# Time to stitch the images: 0:00:11.029303
# Time to calc perpendicular geometry: 0:00:00.000136
# Time to stitch the images: 0:00:11.945397
# Time to calc perpendicular geometry: 0:00:00.000111
# Time to stitch the images: 0:00:12.356743
# Time to calc perpendicular geometry: 0:00:00.000110
# Time to stitch the images: 0:00:12.179014
# Time to calc perpendicular geometry: 0:00:00.000113
# Time to stitch the images: 0:00:12.297606
# Time to calc perpendicular geometry: 0:00:00.000171
# Time to stitch the images: 0:00:11.656261
# Time to calc perpendicular geometry: 0:00:00.000171
# Time to stitch the images: 0:00:12.820533
# Time to calc perpendicular geometry: 0:00:00.000094
# Time to stitch the images: 0:00:13.380867
# Time to calc perpendicular geometry: 0:00:00.000095
# Time to stitch the images: 0:00:14.099184
# Time to calc perpendicular geometry: 0:00:00.000248
# Time to stitch the images: 0:00:12.343100
# Time to calc perpendicular geometry: 0:00:00.000078
# Time to stitch the images: 0:00:14.029917
# Time to calc perpendicular geometry: 0:00:00.000191
# Time to stitch the images: 0:00:11.408180
# Time to calc perpendicular geometry: 0:00:00.000231
# Time to stitch the images: 0:00:12.056720
# Time to calc perpendicular geometry: 0:00:00.000259
# Time to stitch the images: 0:00:10.963276
# Time to calc perpendicular geometry: 0:00:00.000174
# Time to stitch the images: 0:00:14.083693
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:13.091650
# Time to calc perpendicular geometry: 0:00:00.000378
# Time to stitch the images: 0:00:13.008705
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:12.180181
# Time to calc perpendicular geometry: 0:00:00.000175
# Time to stitch the images: 0:00:11.054693
# Time to calc perpendicular geometry: 0:00:00.000091
# Time to stitch the images: 0:00:11.793247
# Time to calc perpendicular geometry: 0:00:00.000082
# Time to stitch the images: 0:00:11.664649
# Time to calc perpendicular geometry: 0:00:00.000095
# Time to stitch the images: 0:00:12.945111
# Time to calc perpendicular geometry: 0:00:00.000097
# Time to stitch the images: 0:00:14.896656
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:15.721024
# Time to calc perpendicular geometry: 0:00:00.000172
# Time to stitch the images: 0:00:16.972382
# Time to calc perpendicular geometry: 0:00:00.000224
# Time to stitch the images: 0:00:17.065641
# Time to calc perpendicular geometry: 0:00:00.000130
# Time to stitch the images: 0:00:17.080710
# Time to calc perpendicular geometry: 0:00:00.000168
# Time to stitch the images: 0:00:16.171487
# Time to calc perpendicular geometry: 0:00:00.000370
# Time to stitch the images: 0:00:15.151573
# Time to calc perpendicular geometry: 0:00:00.000242
# Time to stitch the images: 0:00:13.870080
# Time to calc perpendicular geometry: 0:00:00.000327
# Time to stitch the images: 0:00:13.309361
# Time to calc perpendicular geometry: 0:00:00.000230
# Time to stitch the images: 0:00:12.341685
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:13.796079
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:13.581291
# Time to calc perpendicular geometry: 0:00:00.000153
# Time to stitch the images: 0:00:13.642472
# Time to calc perpendicular geometry: 0:00:00.000154
# Time to stitch the images: 0:00:13.599761
# Time to calc perpendicular geometry: 0:00:00.000126
# Time to stitch the images: 0:00:13.929785
# Time to calc perpendicular geometry: 0:00:00.000153
# Time to stitch the images: 0:00:14.431573
# Time to calc perpendicular geometry: 0:00:00.000243
# Time to stitch the images: 0:00:15.152944
# Time to calc perpendicular geometry: 0:00:00.000143
# Time to stitch the images: 0:00:13.650294
# Time to calc perpendicular geometry: 0:00:00.000144
# Time to stitch the images: 0:00:16.948432
# Time to calc perpendicular geometry: 0:00:00.000140
# Time to stitch the images: 0:00:17.262506
# Time to calc perpendicular geometry: 0:00:00.000202
# Time to stitch the images: 0:00:18.466411
# Time to calc perpendicular geometry: 0:00:00.000245
# Time to stitch the images: 0:00:18.110282
# Time to calc perpendicular geometry: 0:00:00.000322
# Time to stitch the images: 0:00:18.126058
# Time to calc perpendicular geometry: 0:00:00.000112
# Time to stitch the images: 0:00:13.668934
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:12.770903
# Time to calc perpendicular geometry: 0:00:00.000182
# Time to stitch the images: 0:00:12.966677
# Time to calc perpendicular geometry: 0:00:00.000276
# Time to stitch the images: 0:00:13.407715
# Time to calc perpendicular geometry: 0:00:00.000117
# Time to stitch the images: 0:00:13.022336
# Finding dataset maximum / minimum:   0%|          | 0/63 [00:00<?, ?it/s]
# Sample dataset:   0%|          | 0/63 [00:00<?, ?it/s]
# Time to calc perpendicular geometry: 0:00:00.000327
# Time to stitch the images: 0:00:15.750514
# Time to calc perpendicular geometry: 0:00:00.000155
# Time to stitch the images: 0:00:15.274124
# Time to calc perpendicular geometry: 0:00:00.000222
# Time to stitch the images: 0:00:14.316869
# Time to calc perpendicular geometry: 0:00:00.000194
# Time to stitch the images: 0:00:14.550768
# Time to calc perpendicular geometry: 0:00:00.000177
# Time to stitch the images: 0:00:13.934470
# Time to calc perpendicular geometry: 0:00:00.000123
# Time to stitch the images: 0:00:14.560438
# Time to calc perpendicular geometry: 0:00:00.000194
# Time to stitch the images: 0:00:13.361565
# Time to calc perpendicular geometry: 0:00:00.000117
# Time to stitch the images: 0:00:12.811115
# Time to calc perpendicular geometry: 0:00:00.000105
# Time to stitch the images: 0:00:12.053970
# Time to calc perpendicular geometry: 0:00:00.000148
# Time to stitch the images: 0:00:12.864863
# Time to calc perpendicular geometry: 0:00:00.000210
# Time to stitch the images: 0:00:12.835330
# Time to calc perpendicular geometry: 0:00:00.000131
# Time to stitch the images: 0:00:12.785919
# Time to calc perpendicular geometry: 0:00:00.000082
# Time to stitch the images: 0:00:15.848788
# Time to calc perpendicular geometry: 0:00:00.000121
# Time to stitch the images: 0:00:16.275314
# Time to calc perpendicular geometry: 0:00:00.000096
# Time to stitch the images: 0:00:14.832294
# Time to calc perpendicular geometry: 0:00:00.000169
# Time to stitch the images: 0:00:16.153570
# Time to calc perpendicular geometry: 0:00:00.000386
# Time to stitch the images: 0:00:15.581371
# Time to calc perpendicular geometry: 0:00:00.000184
# Time to stitch the images: 0:00:16.097562
# Time to calc perpendicular geometry: 0:00:00.000176
# Time to stitch the images: 0:00:15.093798
# Time to calc perpendicular geometry: 0:00:00.000166
# Time to stitch the images: 0:00:15.744875
# Time to calc perpendicular geometry: 0:00:00.000228
# Time to stitch the images: 0:00:13.819979
# Time to calc perpendicular geometry: 0:00:00.000168
# Time to stitch the images: 0:00:13.209492
# Time to calc perpendicular geometry: 0:00:00.000137
# Time to stitch the images: 0:00:12.104237
# Time to calc perpendicular geometry: 0:00:00.000127
# Time to stitch the images: 0:00:11.756219
# Time to calc perpendicular geometry: 0:00:00.000197
# Time to stitch the images: 0:00:12.315086
# Time to calc perpendicular geometry: 0:00:00.000132
# Time to stitch the images: 0:00:12.950624
# Time to calc perpendicular geometry: 0:00:00.000142
# Time to stitch the images: 0:00:13.281482
# Time to calc perpendicular geometry: 0:00:00.000080

# %% [markdown]
# ##### Render a video

# %%
OVERRIDE: bool = True
"""Whether to override the analysis reduction or not."""

import subprocess
with tqdm.notebook.tqdm(total=len(samples), position=0, leave=True, desc="All Samples") as pbar:
    for i, sample in enumerate(samples):
        ## REQUIRES GLOB SUPPORT BY LIBAVFILTER, NOT INCLUDED IN BUILD BINARIES AVAILALBLE ONLINE.
        # img_path_regex = os.path.normpath(os.path.join(giwaxs_img_dir, f"*.png"))
        # ffmpeg_cmd = f'ffmpeg -framerate 30 -pattern_type glob -i "{img_path_regex}" -c:v libx264 -pix_fmt yuv420p "{vid_path_output}"'
        
        ## Results directory for the sample
        sample_dir = os.path.join(RESULT_DIR, sample)    
        ## Images directory
        giwaxs_img_dir = os.path.join(sample_dir, "giwaxs_flatfielded_images")
        img_list = os.listdir(giwaxs_img_dir)
        
        ai_set = set()
        for img in img_list:
            if not ".png" in img:
                continue
            ai_idx = img.find("deg_")
            ai = img[ai_idx-5:ai_idx]
            if ai in ai_set:
                continue
            ai_set.add(ai)
        
        with tqdm.notebook.tqdm(total=len(ai_set), position=1, leave=False, desc="Angles") as pbar2:
            for ai in ai_set:
                path_img_list =  os.path.normpath(os.path.join(giwaxs_img_dir, f"img_list_ai{ai}.txt"))
                with open(path_img_list, 'w') as f:
                    for img in img_list:
                        if not ".png" in img or not f"{ai}deg" in img:
                            continue
                        # f.write(f"file '{os.path.normpath(os.path.join(giwaxs_img_dir,img))}' duration 0.033333\n")
                        f.write(f"file '{img}'\noutpoint 0.1\n")
                vid_path_output = os.path.normpath(os.path.join(sample_dir, f"{sample}_ai{ai}_beam_energy_scan.mp4"))
                
                ## Check if path exists
                if os.path.exists(vid_path_output) and not OVERRIDE:
                    print("Video already exists, skipping...")
                    pbar.update(1)
                else:
                    if os.path.exists(vid_path_output):
                        os.remove(vid_path_output)
                    ## Video generation
                    ffmpeg_cmd = ['ffmpeg', 
                                '-f', 'concat',
                                #   '-safe', '0'
                                '-i', '"' + path_img_list.replace("\\", "/")  + '"',
                                '-framerate', '30',
                                '-c:v', 'libx264',
                                '-shortest',
                                '-r', '30',
                                '-pix_fmt', 'yuv420p',
                                '-vf', '"pad=ceil(iw/2)*2:ceil(ih/2)*2"',
                                #   '-movflags', 'faststart',
                                #   '-vf', 'format=yuv420p',
                                '"' + vid_path_output + '"']
                    a = subprocess.run(args=" ".join(ffmpeg_cmd), capture_output=True)
                    # Check for errors!
                    display(a.stderr.splitlines())
                pbar2.update(1)
        pbar.update(1)
        if i != len(samples) - 1:
            display("--------------------------------")

# %% [markdown]
# ##### Show the video to check for any inconsistencies

# %%
from IPython.display import Video
for i, sample in enumerate(samples):
    ## Results directory for the sample
    sample_dir = os.path.join(RESULT_DIR, sample)
    file_list = [file for file in os.listdir(sample_dir) if ".mp4" in file]
    file_paths = [os.path.normpath(os.path.join(sample_dir, file)) for file in file_list]
    videos = [Video(file_path, embed=True) for file_path in file_paths]
    for name, video in zip(file_list, videos):
        display(name, video)
